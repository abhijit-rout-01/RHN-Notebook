# %%
### @author     Peitsa Rautio
### @version    01.08.2024

# Summary:

# This .ipynb program imports exported Fluidit format data, builds a pandapipes
# network model and exports it as JSON to ./data/models/.

# In general, dashes in raw node names are converted to underscores due to
# Python syntax not supporting dashes in variable names.
# Dash is strictly an operator type in Python.

# Pandapipes and Pandapower © Copyright 2020-2024 by Fraunhofer Institute for
# Energy Economics and Energy System Technology (IEE), Kassel,
# and University of Kassel.

# %%
# Optional: check if venv is activated

import sys

def is_venv():
    return (hasattr(sys, 'real_prefix') or
            (hasattr(sys, 'base_prefix') and sys.base_prefix != sys.prefix))

if is_venv():
    print('inside virtualenv or venv')
else:
    print('outside virtualenv or venv')
# Out:
# outside virtualenv or venv

# %%
import pandas as pd
import pandapipes as pp
import numpy as np

## Simulation variables and options

# Ambient temperature [K] = t[C] + 273.15
temp_ext_c = 20
temp_ext_k = temp_ext_c + 273.15

# Initial network fluid temperature (flow side) [K] = t[C] + 273.15
t_net_flow_init_c = 105
t_net_flow_init_k = t_net_flow_init_c + 273.15

# Initial network fluid temperature (return side) [K] = t[C] + 273.15
t_net_return_init_c = 35
t_net_return_init_k = t_net_return_init_c + 273.15

# Initial junction and network pressure, flow side [bar]
net_flow_p_bar = 10

# Initial junction and network pressure, return side [bar]
net_return_p_bar = 8

# %%
## Import data from Data.xls into Pandas dataframes

# Define data file path
sourcefile = './data/Data_repair.xlsx'

# Import data
df_heater = pd.read_excel(sourcefile, sheet_name=0)
df_sink = pd.read_excel(sourcefile, sheet_name=1)
df_connection = pd.read_excel(sourcefile, sheet_name=2)
df_nodetype = pd.read_excel(sourcefile, sheet_name=3)

# Prepare blank network for elements
net = pp.create_empty_network(name="Data", fluid="water")
g={}

# %%
def createJunction():
    ## Create pandapipes junctions from imported data.
    # Creates separate networks for supply and return lines. Supply and return
    # lines join at sinks and heat sources.

    # Get number of nodes from dataframe
    num_nodes = len(df_nodetype)

    # tracker tracks number of junctions created
    junction_tracker = 0

    # Iterate over all nodes to find and create junctions
    for i in range(num_nodes):

        if df_nodetype.at[i, 'Node Type'] == "Junction":
            
            # Replace dashes with underscores to conform with Python markup
            junction_name = str(df_nodetype.at[i, 'Name']).replace("Junction-",
                                                                "Junction_")
            
            junction_pos_x = float(df_nodetype.at[i, 'X-Coordinate'])
            junction_pos_y = float(df_nodetype.at[i, 'Y-Coordinate'])
            junction_pos_flow = (junction_pos_x, junction_pos_y)
            junction_pos_return = (junction_pos_x, junction_pos_y-100)

            # Define supply and return flow network junctions
            g['%s_supply' % junction_name] = pp.create_junction(net,
                pn_bar=net_flow_p_bar,
                tfluid_k=t_net_flow_init_k,
                geodata=junction_pos_flow,
                name=junction_name + '_supply')
            g['%s_return' % junction_name] = pp.create_junction(net,
                pn_bar=net_return_p_bar,
                tfluid_k=t_net_return_init_k,
                geodata=junction_pos_return,
                name=junction_name + '_return')

            junction_tracker += 2

    #print("Number of junctions created:", junction_tracker)

    # List junctions
    net.junction

# %% [markdown]
# > &#9658; Information on multiple source heating network models
#
# JanStock1 commented on Feb 26 2024
#
# Hello everyone,
# I would like to comment on this issue as I came up with the same problem of several producers in a district heating network. The solution proposed by @cvTHM worked well for me (additional producers modelled by heat_exchanger and flow_controller). However, since the heat supply and the mass flow are prescribed in this modelling approach (interpreted as base load producer), the supply temperature at these producers is not fixed but depends on the return temperature (temperature difference is fixed). Therefore, the supply temperature at such a producer varies depending on the return temperature, i.e. on the load situation in the district heating network. Thus, the supply temperature at the producers modelled with heat_exchanger and flow_controller is quite low at some load times.
#
# I have tested an alternative approach that ensures a constant supply temperature at the additional producers, but the actual heat supply at these producers differs slightly from the calculated value.
# The first producer in the district heating network is still modelled as a circ_pump_pressure component. The circ_pump_mass component, which prescribes a certain mass flow, can be used (since pandapipes 0.9.0) to specify the temperature at the supply node of additional producers. A heat flow can be calculated using the specified mass flow and the known design temperature difference between supply and return (later more on that). The pressure at the supply node of the circ_pump_mass component must be specified, otherwise there may be no mass flow at the supply node (depending on the pressure conditions in the network). However, if a pressure value is set at the supply nodes of the additional producers (circ_pump_mass) and at the first producer (circ_pump_pressure), the resulting mass flow in the network may not be as desired, as the mass flow follows the fixed pressure conditions in the network. Therefore, a flow_controller is required downstream of the supply node of a circ_pump_mass component, which regulates the pressure conditions and ensures the desired mass flow, which is also set to the circ_pump_mass component but is not yet reached due to the first producer, i.e. the fixed pressure at the circ_pump_pressure component.
#
# The main advantage of this proposed modelling approach (circ_pump_mass and flow_controller) is that the supply temperature at the additional producers can be set. However, as the return temperature at the producers is not known in advance, but the supply temperature and the mass flow are specified, the actually supplied heat at these producers deviates slightly from the calculated value. By varying the set mass flows at the producers depending on the supply condition and the estimated heat losses in the network, the actually supplied heat can be approximated to the aimed value.

# %%
def createSource():
    ## Create pandapipes source nodes

    # See markdown notes above for information on multiple producer networks.

    # Raw source heater values are given as kW [J/s * 10^3], pp circ_pump_mass
    # uses mass flow mkg/s, use conversion ratio variable to adjust.

    # Conversion ratio from raw data, denotes average ratio between base demand
    # [kW] and base demand [kg/s].  Assumes ~50 K / kg of energy heat difference
    # between flow and return networks (210.4648 * 10^3 J/kg / 4190 J/kg ~= 50).
    e_flow_conv_ratio = (7 / 0.033 + 40.3 / 0.193) / 2 # = 210.4648

    # Output water temperature [K] = t[C] + 273.15
    t_out_c = 110
    t_out_k = t_out_c + 273.15

    # Pressure at flow side of producers [bar]
    source_flow_bar = 10

    # Pressure lift induced by sources [bar] - Used to model pressure difference
    # at pump nodes between input and output
    pressure_lift = 3

    # Production multiplier - general multiplier for testing effects of increasing/
    # reducing heated water production. Multiplier applies to mdot_flow_kg_per_s
    prod_multiplier = 1

    # Get source connections and create source nodes
    for i in range(len(df_heater)):
        
        if str(df_heater.iloc[i,0]) != "Ericsson": # Ericsson special case below
            source_name = str(df_heater.iloc[i,0])
            # Define supply and return flow network sources
            source_row=df_nodetype.loc[df_nodetype['Name']==source_name]
            source_pos_flow=(source_row['X-Coordinate'].values[0],source_row['Y-Coordinate'].values[0])
            source_pos_return=(source_row['X-Coordinate'].values[0],source_row['Y-Coordinate'].values[0]-100)
            g['%s_supply' % source_name] = pp.create_junction(net,
                pn_bar=net_flow_p_bar,
                tfluid_k=t_net_flow_init_k+5,
                geodata=source_pos_flow,
                name=source_name + '_supply')
            g['%s_return' % source_name] = pp.create_junction(net,
                pn_bar=net_return_p_bar-1,
                tfluid_k=t_net_return_init_k,
                geodata=source_pos_return,
                name=source_name + '_return')
            
            source_flow=g[source_name+'_supply']
            source_return=g[source_name+'_return']
            
            pp.create_circ_pump_const_pressure(net,
                                                flow_junction=source_flow,
                                                return_junction=source_return,
                                                plift_bar=pressure_lift,
                                                p_flow_bar=source_flow_bar,
                                                mdot_flow_kg_per_s=pd.to_numeric(df_heater.iloc[i,2])/e_flow_conv_ratio,                
                                                t_flow_k=t_out_k,
                                                name=source_name)
            
            for j in range(len(df_connection)):
                
                if str(df_connection.at[j, 'Start Node']) == source_name:
                    
                    junction_flow = g[str(df_connection.at[j, 'End Node'])
                                            .replace("Junction-", "Junction_") + 
                                            '_supply']
                    
                    junction_return = g[str(df_connection.at[j, 'End Node'])
                                            .replace("Junction-", "Junction_") +
                                            '_return']
                    
                    pp.create_pipe_from_parameters(net,
                                                from_junction=source_flow,
                                                to_junction=junction_flow,
                                                length_km=float(str(df_connection.at[j, 'Length [m]']))/1000,
                                                diameter_m=float(str(df_connection.at[j, 'Diameter [mm]']))/1000,
                                                alpha_w_per_m2k=float(str(df_connection.at[j, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                                                text_k=int(temp_ext_k),
                                                name=str(df_connection.at[j,'Name'])+'_supply')

                    pp.create_pipe_from_parameters(net,
                                                from_junction=junction_return,
                                                to_junction=source_return,
                                                length_km=float(str(df_connection.at[j, 'Length [m]']))/1000,
                                                diameter_m=float(str(df_connection.at[j, 'Diameter [mm]']))/1000,
                                                alpha_w_per_m2k=float(str(df_connection.at[j, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                                                text_k=int(temp_ext_k),
                                                name=str(df_connection.at[j,'Name'])+'_supply')
            
                elif str(df_connection.at[j, 'End Node']) == source_name:

                    junction_flow = g[str(df_connection.at[j, 'Start Node'])
                                            .replace("Junction-", "Junction_") + 
                                            '_supply']
                    
                    junction_return = g[str(df_connection.at[j, 'Start Node'])
                                            .replace("Junction-", "Junction_") +
                                            '_return']
                    
                    pp.create_pipe_from_parameters(net,
                                                from_junction=source_flow,
                                                to_junction=junction_flow,
                                                length_km=float(str(df_connection.at[j, 'Length [m]']))/1000,
                                                diameter_m=float(str(df_connection.at[j, 'Diameter [mm]']))/1000,
                                                alpha_w_per_m2k=float(str(df_connection.at[j, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                                                text_k=int(temp_ext_k),
                                                name=str(df_connection.at[j,'Name'])+'_supply')

                    pp.create_pipe_from_parameters(net,
                                                from_junction=junction_return,
                                                to_junction=source_return,
                                                length_km=float(str(df_connection.at[j, 'Length [m]']))/1000,
                                                diameter_m=float(str(df_connection.at[j, 'Diameter [mm]']))/1000,
                                                alpha_w_per_m2k=float(str(df_connection.at[j, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                                                text_k=int(temp_ext_k),
                                                name=str(df_connection.at[j,'Name'])+'_supply')
            
    # Ericsson special case: Ericsson has only return connections;
    # Ericsson set as a slack node in the network.

    # Create auxiliary junction to connect to Ericsson
    Ericsson_row = df_nodetype.loc[df_nodetype['Name']=='Ericsson']
    Ericsson_geodata = (Ericsson_row.loc[:,'X-Coordinate'].values[0],Ericsson_row.loc[:,'Y-Coordinate'].values[0])
    g['Ericsson_connection'] = pp.create_junction(
                                        net, pn_bar=net_return_p_bar,
                                        tfluid_k=t_net_return_init_k,
                                        geodata=Ericsson_geodata,
                                        name='Ericsson_connection')

    # Tracker for Ericsson auxiliary junction connections
    e_pipe_tracker = 0

    for i in range(len(df_connection)):

        if str(df_connection.at[i, 'Start Node']) == 'Ericsson':
                    
            connection_name = g[str(df_connection.at[i, 'End Node'])
                                            .replace("Junction-", "Junction_") + 
                                            '_return']

            pp.create_pipe_from_parameters(net,
                from_junction=connection_name,
                to_junction=g['Ericsson_connection'],
                length_km=float(str(df_connection.at[i, 'Length [m]']))/1000,
                diameter_m=float(str(df_connection.at[i, 'Diameter [mm]']))/1000,
                alpha_w_per_m2k=float(str(df_connection.at[i, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                text_k=int(temp_ext_k),
                name='Pipe_E_' + str(e_pipe_tracker)
                )
            
            e_pipe_tracker += 1
            
        elif str(df_connection.at[i, 'End Node']) == 'Ericsson':

            connection_name = g[str(df_connection.at[i, 'Start Node'])
                                            .replace("Junction-", "Junction_") + 
                                            '_return']

            pp.create_pipe_from_parameters(net,
                from_junction=connection_name,
                to_junction=g['Ericsson_connection'],
                length_km=float(str(df_connection.at[i, 'Length [m]']))/1000,
                diameter_m=float(str(df_connection.at[i, 'Diameter [mm]']))/1000,
                k_mm=.05,
                alpha_w_per_m2k=float(str(df_connection.at[i, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                text_k=int(temp_ext_k),
                name='Pipe_E_' + str(i)
                )
            
            e_pipe_tracker += 1

    # Create Ericsson slack node

    Ericsson = pp.create_ext_grid(net,
                                junction=g['Ericsson_connection'],
                                p_bar=net_return_p_bar,
                                t_k=t_net_return_init_k,
                                name="Ericsson Ext. Grid")


    # List sources
    net.circ_pump_pressure
    #help(pp.create_pipe_from_parameters)

# %%
def createSink(col):
    ## Create pandapipes sink nodes

    # Desired return water temperature [K] = t[C] + 273.15
    # Use t_return_c = t_net_return_init_c to set to initial network temp
    t_return_c = t_net_return_init_c + 5
    t_return_k = t_return_c + 273.15

    #demand in kW
    col_name=df_sink.columns[col]
    # Get number of sinks and connections
    num_sinks = len(df_sink)
    num_connections = len(df_connection)

    # Tracker tracks number of sinks created
    sink_tracker = 0

    # Iterate over number of raw data rows to find and create sinks
    for i in range(num_sinks):

        sink_get = str(df_sink.at[i, 'Name'])
        sink_name=sink_get.replace('Junction-','Sink_')
        # Get sink details
        sink_type = str(df_sink.at[i, 'Category'])
        sink_priority = int(float(str(df_sink.at[i, 'Priority'])))
        sink_demand_kW = float(str(df_sink.at[i, col_name]))
        mdot_kg_per_s_demand = float(str(df_sink.at[i, 'Base Demand [kg/s]']))
        sink_x = float(str(df_sink.at[i, 'X-Coordinate']))
        sink_y = float(str(df_sink.at[i, 'Y-Coordinate']))

        g[sink_get.replace('Junction-','Sink_')+'_supply']=pp.create_junction(net,
                                                                            pn_bar=net_flow_p_bar,
                                                                            tfluid_k=t_net_flow_init_k,
                                                                            geodata=(sink_x,sink_y),
                                                                            name=sink_get.replace('Junction-','Sink_') + '_supply')
        g[sink_get.replace('Junction-','Sink_')+'_return']=pp.create_junction(net,
                                                                            pn_bar=net_return_p_bar,
                                                                            tfluid_k=t_net_return_init_k,
                                                                            geodata=(sink_x,sink_y-100),
                                                                            name=sink_get.replace('Junction-','Sink_') + '_return')
        # Define sink
        pp.create_heat_consumer(net,
                                from_junction=g[sink_get.replace('Junction-','Sink_')+'_supply'],
                                to_junction=g[sink_get.replace('Junction-','Sink_')+'_return'],
                                diameter_m=43.1/1000,
                                qext_w=sink_demand_kW*1000,
                                # controlled_mdot_kg_per_s=mdot_kg_per_s_capacity,
                                #controlled_mdot_kg_per_s=mdot_kg_per_s_demand,
                                # deltat_k=50,
                                treturn_k=t_return_k,
                                name=sink_name, type=sink_type
                                )
        
        sink_flow = g[sink_get.replace('Junction-','Sink_')+'_supply']
        sink_return = g[sink_get.replace('Junction-','Sink_')+'_return']
        # Get connecting junction and pipe diameter
        for k in range(num_connections):
            if df_connection.at[k, "End Node"] == sink_get:
                junction_source = g[str(df_connection.at[k, 'Start Node']).
                                        replace("Junction-", "Junction_") + '_supply']
                junction_return = g[str(df_connection.at[k, 'Start Node']).
                                        replace("Junction-", "Junction_") + '_return']
                connection_d_mm = float(str(df_connection.at[k, 'Diameter [mm]']))
                mdot_kg_per_s_capacity = float(str(df_connection.at[k, 'Capacity [kg/s]']))
                
                pp.create_pipe_from_parameters(net,
                    from_junction=junction_source,
                    to_junction=sink_flow,
                    length_km=float(str(df_connection.at[k, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[k, 'Diameter [mm]']))/1000,
                    alpha_w_per_m2k=float(str(df_connection.at[k, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    text_k=int(temp_ext_k),
                    name=str(df_connection.at[k,'Name']+'_supply')
                    )
                pp.create_pipe_from_parameters(net,
                    from_junction=sink_return,
                    to_junction=junction_return,
                    length_km=float(str(df_connection.at[k, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[k, 'Diameter [mm]']))/1000,
                    alpha_w_per_m2k=float(str(df_connection.at[k, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    text_k=int(temp_ext_k),
                    name=str(df_connection.at[k,'Name']+'_return')
                    ) 

            elif df_connection.at[k, "Start Node"] == sink_get:
                junction_source = g[str(df_connection.at[k, 'End Node']).
                                        replace("Junction-", "Junction_") + '_supply']
                junction_return = g[str(df_connection.at[k, 'End Node']).
                                        replace("Junction-", "Junction_") + '_return']
                connection_d_mm = float(str(df_connection.at[k, 'Diameter [mm]']))
                mdot_kg_per_s_capacity = float(str(df_connection.at[k, 'Capacity [kg/s]']))
                pp.create_pipe_from_parameters(net,
                    from_junction=junction_source,
                    to_junction=sink_flow,
                    length_km=float(str(df_connection.at[k, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[k, 'Diameter [mm]']))/1000,
                    alpha_w_per_m2k=float(str(df_connection.at[k, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    text_k=int(temp_ext_k),
                    name=str(df_connection.at[k,'Name']+'_supply')
                    )
                pp.create_pipe_from_parameters(net,
                    from_junction=sink_return,
                    to_junction=junction_return,
                    length_km=float(str(df_connection.at[k, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[k, 'Diameter [mm]']))/1000,
                    alpha_w_per_m2k=float(str(df_connection.at[k, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    text_k=int(temp_ext_k),
                    name=str(df_connection.at[k,'Name']+'_return')
                    )  
            
        sink_tracker += 1

    #help(pp.create_heat_consumer)
    #print("Number of sinks created:", sink_tracker)
    net.heat_consumer

# %%
def createPipe():
    ## Create pipe connections

    # Defines pipe connections between junctions. Source and sink connections
    # are defined at heat pump node and heat exchanger creation.

    # Tracker tracks number of pipes created
    pipe_tracker = 0

    # Concatenate source and sink names to single NumPy array
    np_heaters_sinks = pd.concat([df_heater[['Name']], df_sink[['Name']]]).to_numpy()
    num_heaters_sinks = len(np_heaters_sinks)
    num_connections = len(df_connection)
    for i in range(num_connections):
        
        pipe_get = str(df_connection.at[i, 'Name']).replace("-", "_")

        start_node = str(df_connection.at[i, 'Start Node'])
        end_node = str(df_connection.at[i, 'End Node'])

        if str(df_connection.at[i, 'Has Supply Line']) == 'True': supply_line = True
        else: supply_line = False
        if str(df_connection.at[i, 'Has Return Line']) == 'True': return_line = True
        else: return_line = False
    
        # Exclude source and sink node connections (defined earlier)
        if start_node not in np_heaters_sinks and end_node not in np_heaters_sinks:
                
            # Create supply line pipe
            if supply_line == True:
                
                pipe_from = g[str(df_connection.at[i, 'Start Node']).
                                    replace("Junction-", "Junction_") + '_supply']
                pipe_to = g[str(df_connection.at[i, 'End Node']).
                                    replace("Junction-", "Junction_") + '_supply']
                pipe_name = pipe_get + '_supply'

                pp.create_pipe_from_parameters(net,
                    from_junction=pipe_from,
                    to_junction=pipe_to,
                    length_km=float(str(df_connection.at[i, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[i, 'Diameter [mm]']))/1000,
                    k_mm=.05,
                    alpha_w_per_m2k=float(str(df_connection.at[i, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    sections=5,
                    text_k=int(temp_ext_k),
                    name=pipe_name
                    )
                pipe_tracker += 1
            
            # Create return line pipe
            if return_line == True:

                pipe_from = g[str(df_connection.at[i, 'End Node']).
                    replace("Junction-", "Junction_") + '_return']
                pipe_to = g[str(df_connection.at[i, 'Start Node']).
                    replace("Junction-", "Junction_") + '_return']
                pipe_name = pipe_get + '_return'

                pp.create_pipe_from_parameters(net,
                    from_junction=pipe_from,
                    to_junction=pipe_to,
                    length_km=float(str(df_connection.at[i, 'Length [m]']))/1000,
                    diameter_m=float(str(df_connection.at[i, 'Diameter [mm]']))/1000,
                    alpha_w_per_m2k=float(str(df_connection.at[i, 'Heat Transfer Coefficient [W/mK]'])), # W/mK from raw data
                    text_k=int(temp_ext_k),
                    name=pipe_name,
                    sections=5,
                    k_mm=.05
                    )
                pipe_tracker += 1

    #print("Number of pipes created: ", pipe_tracker)
    net.pipe

# %%
net.pipe.name
# Out:
# Series([], Name: name, dtype: object)

# %%
## Code for inspecting elements and debugging

# net.junction.loc(Junction_1000_return)

# Plotting
import pandapipes.plotting as plot

def netPlot():
    plot.simple_plot(net, plot_sinks=True, plot_sources=True,
                    junction_size=0.2, heat_consumer_size=0.5,
                    heat_consumer_color='Teal', pump_size=0.5,
                    pump_color='Blue')

# %%
def setParams(mid):
    global t_net_flow_init_k,t_out_k
    t_net_flow_init_k=mid-5
    t_out_k=mid

# %%
def run(col):
    ## Run pipeflow
    createJunction()
    createSource()
    createSink(col)
    createPipe()
    #netPlot()
    pp.pipeflow(net, mode='sequential')#,iter=10000) # Modes = hydraulics, sequential, bidirectional
    
    return net.res_circ_pump_pressure.at[0,'mdot_flow_kg_per_s']+net.res_circ_pump_pressure.at[1,'mdot_flow_kg_per_s']

# %%
# def setInitial_mdot():
#     net.res_heat_consumer.to_csv('initial_mdot_sinks.csv',Index=False)

# %%
# Initializations
temp = 90
net = pp.create_empty_network(name="Data", fluid="water")

setParams(temp + 273.15)
total_mdot_kg_per_s = 193.022376298
col = 9
s, e = 80.0, 95.0
iter = 0
mid = 0
prev_mid = None  # To detect oscillation

# Optimizer
while s <= e and iter < 30:
    iter += 1
    mid = (s + e) / 2.0
    setParams(mid + 273.15)
    net = pp.create_empty_network(name="Data", fluid="water")
    # Run simulation
    total_mdot_kg_per_s_INST = abs(run(col))
    
    # Calculate relative error
    error = abs(total_mdot_kg_per_s_INST - total_mdot_kg_per_s)
    #rel_error = error / total_mdot_kg_per_s
    
    # Check convergence
    if error <= 1.0:  # 1% error tolerance
        print("\nConverged!")
        print(f"Optimal Temp: {mid:.2f}°C")
        print(f"Obtained mdot: {total_mdot_kg_per_s_INST:.4f} kg/s")
        print(f"Required mdot: {total_mdot_kg_per_s} kg/s")
        break
    
    # Adjust search range with adaptive step size
    step = max(0.1, error / 10)  # Minimum step of 0.1, dynamically adjusted
    
    if total_mdot_kg_per_s_INST > total_mdot_kg_per_s:
        s = mid + step
    else:
        e = mid - step
    
    # Early exit if oscillation detected
    if prev_mid is not None and abs(mid - prev_mid) < 0.05:
        print("\nOscillation detected, stopping early.")
        break
    prev_mid = mid
    
    # Logging
    print(f"Temp = {mid:.2f}°C")
    print(f"\tObtained mdot: {total_mdot_kg_per_s_INST:.4f} kg/s")
    print(f"\tRequired mdot: {total_mdot_kg_per_s} kg/s")
# Out:
# Temp = 87.50°C
# 	Obtained mdot: 210.8636 kg/s
# 	Required mdot: 193.022376298 kg/s
# Temp = 92.14°C
# 	Obtained mdot: 190.0462 kg/s
# 	Required mdot: 193.022376298 kg/s
# Temp = 90.56°C
# 	Obtained mdot: 196.6459 kg/s
# 	Required mdot: 193.022376298 kg/s
#
# Converged!
# Optimal Temp: 91.39°C
# Obtained mdot: 193.1546 kg/s
# Required mdot: 193.022376298 kg/s

# %%
#Initializations
temp=90
g={}
net=pp.create_empty_network(name='Data',fluid='water')

setParams(temp+273.15)
total_mdot_kg_per_s=193.022376298
print(total_mdot_kg_per_s)
col=9
s=80.0
e=95
iter=0
mid=0
# Optimizer
while s<=e and iter<30:
    g={}
    net=pp.create_empty_network(name='Data',fluid='water')
    iter+=1
    mid=(s+e)/2.0
    setParams(mid+273.15)
    total_mdot_kg_per_s_INST=abs(run(col))
    if abs(total_mdot_kg_per_s_INST-total_mdot_kg_per_s)<=0.2:
        # print('\nHI')
        print(f'Temp = {mid}')
        print(f'\tObtained mdot {total_mdot_kg_per_s_INST}')
        print(f'\tReq mdot {total_mdot_kg_per_s}')
        break
    elif total_mdot_kg_per_s_INST>total_mdot_kg_per_s:
        s=mid+0.1
    elif total_mdot_kg_per_s_INST<total_mdot_kg_per_s:
        e=mid-0.1
    print(f'Temp = {mid}')
    print(f'\tObtained mdot {total_mdot_kg_per_s_INST}')
    print(f'\tReq mdot {total_mdot_kg_per_s}')
# Out:
# 193.022376298
# Temp = 87.5
# 	Obtained mdot 210.86360347819547
# 	Req mdot 193.022376298
# Temp = 91.3
# 	Obtained mdot 193.5125060005139
# 	Req mdot 193.022376298
# Temp = 93.19999999999999
# 	Obtained mdot 185.8629113654209
# 	Req mdot 193.022376298
# Temp = 92.25
# 	Obtained mdot 189.6108073614423
# 	Req mdot 193.022376298
# Temp = 91.775
# 	Obtained mdot 191.54184565104794
# 	Req mdot 193.022376298
# Temp = 91.5375
# 	Obtained mdot 192.52214724042722
# 	Req mdot 193.022376298
# Temp = 91.41874999999999
# 	Obtained mdot 193.01605982590695
# 	Req mdot 193.022376298

# %%
net.pipe
# Out:
#                     name  from_junction  to_junction std_type  length_km  \
# 0     Pipe-102854_supply           1588          170     None    0.37059
# 1     Pipe-102854_supply            171         1589     None    0.37059
# 2      Pipe-58425_supply           1590           74     None    0.00368
# 3      Pipe-58425_supply             75         1591     None    0.00368
# 4              Pipe_E_97            201         1592     None    0.12795
# 5            Pipe_E_1064           1345         1592     None    0.00484
# 6     Pipe-133431_supply           1556         1593     None    0.00064
# 7     Pipe-133431_return           1594         1557     None    0.00064
# 8     Pipe-131675_supply           1470         1595     None    0.03267
# 9     Pipe-131675_return           1596         1471     None    0.03267
# 10    Pipe-131624_supply           1458         1597     None    0.06873
# 11    Pipe-131624_return           1598         1459     None    0.06873
# 12    Pipe-132621_supply           1464         1599     None    0.00071
# 13    Pipe-132621_return           1600         1465     None    0.00071
# 14    Pipe-132930_supply           1546         1601     None    0.03012
# 15    Pipe-132930_return           1602         1547     None    0.03012
# 16    Pipe-132952_supply           1544         1603     None    0.03618
# 17    Pipe-132952_return           1604         1545     None    0.03618
# 18    Pipe-132776_supply           1542         1605     None    0.00780
# 76    Pipe-110935_supply           1034         1661     None    0.06593
# 77    Pipe-110935_return           1662         1035     None    0.06593
# 78    Pipe-100993_supply           1244         1663     None    0.02313
# 79    Pipe-100993_return           1664         1245     None    0.02313
# 80    Pipe-100986_supply             32         1665     None    0.05153
# 81    Pipe-100986_return           1666           33     None    0.05153
# 82    Pipe-100983_supply            956         1667     None    0.01287
# 83    Pipe-100983_return           1668          957     None    0.01287
# 84    Pipe-100981_supply           1242         1669     None    0.03573
# 85    Pipe-100981_return           1670         1243     None    0.03573
# 86    Pipe-100617_supply           1162         1671     None    0.12591
# 87    Pipe-100617_return           1672         1163     None    0.12591
# 88    Pipe-100266_supply           1144         1673     None    0.11199
# 89    Pipe-100266_return           1674         1145     None    0.11199
# 90    Pipe-100952_supply           1140         1675     None    0.01780
# 91    Pipe-100952_return           1676         1141     None    0.01780
# 92    Pipe-100901_supply           1234         1677     None    0.01128
# 93    Pipe-100901_return           1678         1235     None    0.01128
# 94    Pipe-100864_supply            838         1679     None    0.01734
# 95    Pipe-100864_return           1680          839     None    0.01734
# 96    Pipe-100836_supply           1144         1681     None    0.01087
# 97    Pipe-100836_return           1682         1145     None    0.01087
# 98    Pipe-100800_supply           1220         1683     None    0.01044
# 99    Pipe-100800_return           1684         1221     None    0.01044
# 100   Pipe-100778_supply            322         1685     None    0.04302
# 101   Pipe-100778_return           1686          323     None    0.04302
# 102   Pipe-100776_supply           1218         1687     None    0.00691
# 103   Pipe-100776_return           1688         1219     None    0.00691
# 104   Pipe-100771_supply           1218         1689     None    0.04335
# 105   Pipe-100771_return           1690         1219     None    0.04335
# 106   Pipe-100768_supply           1034         1691     None    0.05043
# 107   Pipe-100768_return           1692         1035     None    0.05043
# 108   Pipe-100755_supply           1216         1693     None    0.00656
# 109   Pipe-100755_return           1694         1217     None    0.00656
# 110   Pipe-100753_supply           1214         1695     None    0.00670
# 111   Pipe-100753_return           1696         1215     None    0.00670
# 112   Pipe-100750_supply           1210         1697     None    0.00815
# 113   Pipe-100750_return           1698         1211     None    0.00815
# 114   Pipe-100749_supply           1210         1699     None    0.00386
# 115   Pipe-100749_return           1700         1211     None    0.00386
# 116   Pipe-100747_supply           1194         1701     None    0.01974
# 117   Pipe-100747_return           1702         1195     None    0.01974
# 118   Pipe-100732_supply           1136         1703     None    0.02329
# 119   Pipe-100732_return           1704         1137     None    0.02329
# 120   Pipe-100718_supply            528         1705     None    0.15755
# 121   Pipe-100718_return           1706          529     None    0.15755
# 122   Pipe-132494_supply           1528         1707     None    0.00348
# 123   Pipe-132494_return           1708         1529     None    0.00348
# 124   Pipe-100668_supply           1154         1709     None    0.02719
# 125   Pipe-100668_return           1710         1155     None    0.02719
# 126   Pipe-135606_supply           1536         1711     None    0.01160
# 127   Pipe-135606_return           1712         1537     None    0.01160
# 128   Pipe-100649_supply           1206         1713     None    0.00558
# 129   Pipe-100649_return           1714         1207     None    0.00558
# 130   Pipe-100646_supply           1202         1715     None    0.00848
# 131   Pipe-100646_return           1716         1203     None    0.00848
# 246    Pipe-99847_supply           1070         1831     None    0.07200
# 247    Pipe-99847_return           1832         1071     None    0.07200
# 248   Pipe-100962_supply           1150         1833     None    0.04941
# 249   Pipe-100962_return           1834         1151     None    0.04941
# 250   Pipe-135674_supply           1550         1835     None    0.06485
# 251   Pipe-135674_return           1836         1551     None    0.06485
# 252    Pipe-99717_supply           1066         1837     None    0.01456
# 253    Pipe-99717_return           1838         1067     None    0.01456
# 254    Pipe-99715_supply           1060         1839     None    0.00485
# 255    Pipe-99715_return           1840         1061     None    0.00485
# 256    Pipe-99712_supply           1056         1841     None    0.01775
# 257    Pipe-99712_return           1842         1057     None    0.01775
# 258    Pipe-99654_supply           1046         1843     None    0.00870
# 259    Pipe-99654_return           1844         1047     None    0.00870
# 260     Pipe-9556_supply            236         1845     None    0.08185
# 261     Pipe-9556_return           1846          237     None    0.08185
# 262    Pipe-99645_supply           1052         1847     None    0.02388
# 263    Pipe-99645_return           1848         1053     None    0.02388
# 264    Pipe-99521_supply            532         1849     None    0.03643
# 265    Pipe-99521_return           1850          533     None    0.03643
# 266   Pipe-136114_supply           1050         1851     None    0.05491
# 267   Pipe-136114_return           1852         1051     None    0.05491
# 268    Pipe-99300_supply            706         1853     None    0.01385
# 269    Pipe-99300_return           1854          707     None    0.01385
# 270    Pipe-99283_supply            998         1855     None    0.05357
# 271    Pipe-99283_return           1856          999     None    0.05357
# 272    Pipe-99266_supply           1012         1857     None    0.03195
# 273    Pipe-99266_return           1858         1013     None    0.03195
# 274   Pipe-131670_supply           1468         1859     None    0.03279
# 275   Pipe-131670_return           1860         1469     None    0.03279
# 276    Pipe-99077_supply           1016         1861     None    0.00465
# 277    Pipe-99077_return           1862         1017     None    0.00465
# 278    Pipe-99076_supply           1016         1863     None    0.00769
# 279    Pipe-99076_return           1864         1017     None    0.00769
# 280   Pipe-110839_supply           1380         1865     None    0.10481
# 281   Pipe-110839_return           1866         1381     None    0.10481
# 282    Pipe-38896_supply            668         1867     None    0.04856
# 283    Pipe-38896_return           1868          669     None    0.04856
# 284    Pipe-98721_supply            972         1869     None    0.05148
# 285    Pipe-98721_return           1870          973     None    0.05148
# 286   Pipe-135553_supply            936         1871     None    0.03002
# 287   Pipe-135553_return           1872          937     None    0.03002
# 288   Pipe-110855_supply           1020         1873     None    0.11574
# 289   Pipe-110855_return           1874         1021     None    0.11574
# 290    Pipe-98414_supply           1036         1875     None    0.01990
# 291    Pipe-98414_return           1876         1037     None    0.01990
# 292    Pipe-98408_supply           1032         1877     None    0.00968
# 293    Pipe-98408_return           1878         1033     None    0.00968
# 294    Pipe-98395_supply           1030         1879     None    0.04008
# 295    Pipe-98395_return           1880         1031     None    0.04008
# 296    Pipe-98152_supply           1024         1881     None    0.09055
# 297    Pipe-98152_return           1882         1025     None    0.09055
# 298    Pipe-98046_supply           1006         1883     None    0.28796
# 299    Pipe-98046_return           1884         1007     None    0.28796
# 300    Pipe-98037_supply           1000         1885     None    0.01251
# 301    Pipe-98037_return           1886         1001     None    0.01251
# 302    Pipe-97733_supply            968         1887     None    0.01114
# 303    Pipe-97733_return           1888          969     None    0.01114
# 304   Pipe-135492_supply           1018         1889     None    0.00955
# 305   Pipe-135492_return           1890         1019     None    0.00955
# 306    Pipe-97486_supply            502         1891     None    0.29624
# 307    Pipe-97486_return           1892          503     None    0.29624
# 308     Pipe-9500_supply            226         1893     None    0.00174
# 309     Pipe-9500_return           1894          227     None    0.00174
# 310   Pipe-135590_supply           1444         1895     None    0.04373
# 311   Pipe-135590_return           1896         1445     None    0.04373
# 312    Pipe-97125_supply           1010         1897     None    0.01044
# 313    Pipe-97125_return           1898         1011     None    0.01044
# 314    Pipe-97121_supply           1008         1899     None    0.00341
# 315    Pipe-97121_return           1900         1009     None    0.00341
# 316    Pipe-96860_supply           1004         1901     None    0.00698
# 317    Pipe-96860_return           1902         1005     None    0.00698
# 318    Pipe-96388_supply            994         1903     None    0.12006
# 319    Pipe-96388_return           1904          995     None    0.12006
# 320    Pipe-96046_supply            986         1905     None    0.10093
# 321    Pipe-96046_return           1906          987     None    0.10093
# 322    Pipe-95573_supply            988         1907     None    0.02836
# 323    Pipe-95573_return           1908          989     None    0.02836
# 324      Pipe-925_supply             22         1909     None    0.06494
# 325      Pipe-925_return           1910           23     None    0.06494
# 326    Pipe-95214_supply            978         1911     None    0.01777
# 327    Pipe-95214_return           1912          979     None    0.01777
# 328    Pipe-95142_supply            982         1913     None    0.01167
# 329    Pipe-95142_return           1914          983     None    0.01167
# 330    Pipe-95193_supply            980         1915     None    0.06906
# 331    Pipe-95193_return           1916          981     None    0.06906
# 332   Pipe-132017_supply           1582         1917     None    0.03463
# 333   Pipe-132017_return           1918         1583     None    0.03463
# 334     Pipe-9234_supply            222         1919     None    0.07116
# 335     Pipe-9234_return           1920          223     None    0.07116
# 336   Pipe-135408_supply           1450         1921     None    0.04311
# 337   Pipe-135408_return           1922         1451     None    0.04311
# 338    Pipe-94317_supply            996         1923     None    0.01540
# 339    Pipe-94317_return           1924          997     None    0.01540
# 340      Pipe-892_supply             20         1925     None    0.04336
# 341      Pipe-892_return           1926           21     None    0.04336
# 342    Pipe-95806_supply            964         1927     None    0.04138
# 343    Pipe-95806_return           1928          965     None    0.04138
# 344      Pipe-843_supply              4         1929     None    0.00701
# 345      Pipe-843_return           1930            5     None    0.00701
# 346    Pipe-78220_supply            634         1931     None    0.00263
# 347    Pipe-78220_return           1932          635     None    0.00263
# 348     Pipe-7927_supply            206         1933     None    0.01211
# 349     Pipe-7927_return           1934          207     None    0.01211
# 350     Pipe-6393_supply            164         1935     None    0.10334
# 351     Pipe-6393_return           1936          165     None    0.10334
# 352    Pipe-72048_supply            952         1937     None    0.00179
# 353    Pipe-72048_return           1938          953     None    0.00179
# 354    Pipe-71772_supply            606         1939     None    0.10594
# 355    Pipe-71772_return           1940          607     None    0.10594
# 356     Pipe-7388_supply            196         1941     None    0.00199
# 357     Pipe-7388_return           1942          197     None    0.00199
# 358    Pipe-70122_supply            952         1943     None    0.00171
# 359    Pipe-70122_return           1944          953     None    0.00171
# 360    Pipe-70265_supply            942         1945     None    0.04484
# 361    Pipe-70265_return           1946          943     None    0.04484
# 362    Pipe-73738_supply            854         1947     None    0.01383
# 363    Pipe-73738_return           1948          855     None    0.01383
# 364    Pipe-64038_supply            928         1949     None    0.04339
# 365    Pipe-64038_return           1950          929     None    0.04339
# 366      Pipe-696_supply             30         1951     None    0.04836
# 367      Pipe-696_return           1952           31     None    0.04836
# 368    Pipe-67845_supply            940         1953     None    0.00285
# 369    Pipe-67845_return           1954          941     None    0.00285
# 370    Pipe-67844_supply            940         1955     None    0.01936
# 371    Pipe-67844_return           1956          941     None    0.01936
# 372    Pipe-71179_supply            960         1957     None    0.06799
# 373    Pipe-71179_return           1958          961     None    0.06799
# 374     Pipe-7047_supply            184         1959     None    0.03147
# 375     Pipe-7047_return           1960          185     None    0.03147
# 376    Pipe-64111_supply            938         1961     None    0.14093
# 377    Pipe-64111_return           1962          939     None    0.14093
# 378    Pipe-71700_supply            958         1963     None    0.02250
# 379    Pipe-71700_return           1964          959     None    0.02250
# 380    Pipe-66069_supply            934         1965     None    0.02551
# 381    Pipe-66069_return           1966          935     None    0.02551
# 382     Pipe-6930_supply            180         1967     None    0.01270
# 383     Pipe-6930_return           1968          181     None    0.01270
# 384    Pipe-63116_supply            620         1969     None    0.04738
# 385    Pipe-63116_return           1970          621     None    0.04738
# 386    Pipe-62425_supply            920         1971     None    0.00249
# 387    Pipe-62425_return           1972          921     None    0.00249
# 388    Pipe-62424_supply            920         1973     None    0.00523
# 389    Pipe-62424_return           1974          921     None    0.00523
# 390    Pipe-60184_supply            914         1975     None    0.03059
# 391    Pipe-60184_return           1976          915     None    0.03059
# 392     Pipe-6489_supply            172         1977     None    0.04517
# 393     Pipe-6489_return           1978          173     None    0.04517
# 394     Pipe-6483_supply            162         1979     None    0.00947
# 395     Pipe-6483_return           1980          163     None    0.00947
# 396    Pipe-61853_supply            878         1981     None    0.02254
# 397    Pipe-61853_return           1982          879     None    0.02254
# 398     Pipe-6735_supply            176         1983     None    0.01517
# 399     Pipe-6735_return           1984          177     None    0.01517
# 400    Pipe-61161_supply            656         1985     None    0.02104
# 401    Pipe-61161_return           1986          657     None    0.02104
# 402    Pipe-60922_supply            924         1987     None    0.02645
# 403    Pipe-60922_return           1988          925     None    0.02645
# 404     Pipe-6355_supply            166         1989     None    0.02208
# 405     Pipe-6355_return           1990          167     None    0.02208
# 406    Pipe-60478_supply            866         1991     None    0.03752
# 407    Pipe-60478_return           1992          867     None    0.03752
# 408    Pipe-60457_supply            626         1993     None    0.02666
# 409    Pipe-60457_return           1994          627     None    0.02666
# 410    Pipe-62448_supply            572         1995     None    0.02995
# 411    Pipe-62448_return           1996          573     None    0.02995
# 412    Pipe-60222_supply            646         1997     None    0.01942
# 413    Pipe-60222_return           1998          647     None    0.01942
# 414    Pipe-60503_supply            600         1999     None    0.04846
# 415    Pipe-60503_return           2000          601     None    0.04846
# 416    Pipe-60117_supply            644         2001     None    0.00983
# 417    Pipe-60117_return           2002          645     None    0.00983
# 418    Pipe-59742_supply            904         2003     None    0.01065
# 419    Pipe-59742_return           2004          905     None    0.01065
# 420    Pipe-59665_supply            902         2005     None    0.02977
# 421    Pipe-59665_return           2006          903     None    0.02977
# 422    Pipe-59271_supply            900         2007     None    0.01876
# 423    Pipe-59271_return           2008          901     None    0.01876
# 424    Pipe-58876_supply            906         2009     None    0.04118
# 425    Pipe-58876_return           2010          907     None    0.04118
# 426    Pipe-58865_supply            888         2011     None    0.02327
# 427    Pipe-58865_return           2012          889     None    0.02327
# 428    Pipe-57352_supply            908         2013     None    0.03451
# 429    Pipe-57352_return           2014          909     None    0.03451
# 430    Pipe-56933_supply            886         2015     None    0.05035
# 431    Pipe-56933_return           2016          887     None    0.05035
# 432     Pipe-5942_supply            158         2017     None    0.03127
# 433     Pipe-5942_return           2018          159     None    0.03127
# 434    Pipe-55018_supply            870         2019     None    0.02277
# 435    Pipe-55018_return           2020          871     None    0.02277
# 436    Pipe-55000_supply            860         2021     None    0.01890
# 437    Pipe-55000_return           2022          861     None    0.01890
# 438    Pipe-54905_supply            868         2023     None    0.04469
# 439    Pipe-54905_return           2024          869     None    0.04469
# 440   Pipe-102913_supply           1344         2025     None    0.00263
# 441   Pipe-102913_return           2026         1345     None    0.00263
# 442    Pipe-54764_supply            856         2027     None    0.02612
# 443    Pipe-54764_return           2028          857     None    0.02612
# 444    Pipe-53833_supply            764         2029     None    0.06710
# 445    Pipe-53833_return           2030          765     None    0.06710
# 446     Pipe-5789_supply            156         2031     None    0.10217
# 447     Pipe-5789_return           2032          157     None    0.10217
# 448    Pipe-53395_supply            862         2033     None    0.00853
# 449    Pipe-53395_return           2034          863     None    0.00853
# 450    Pipe-52891_supply            858         2035     None    0.00279
# 451    Pipe-52891_return           2036          859     None    0.00279
# 452    Pipe-50712_supply            844         2037     None    0.01935
# 453    Pipe-50712_return           2038          845     None    0.01935
# 454    Pipe-51524_supply            588         2039     None    0.05139
# 455    Pipe-51524_return           2040          589     None    0.05139
# 456    Pipe-52132_supply            846         2041     None    0.00667
# 457    Pipe-52132_return           2042          847     None    0.00667
# 458    Pipe-51927_supply            810         2043     None    0.03607
# 459    Pipe-51927_return           2044          811     None    0.03607
# 460    Pipe-51863_supply            776         2045     None    0.04409
# 461    Pipe-51863_return           2046          777     None    0.04409
# 462    Pipe-51164_supply            836         2047     None    0.07378
# 463    Pipe-51164_return           2048          837     None    0.07378
# 464    Pipe-51626_supply            830         2049     None    0.02191
# 465    Pipe-51626_return           2050          831     None    0.02191
# 466    Pipe-51504_supply            748         2051     None    0.02472
# 467    Pipe-51504_return           2052          749     None    0.02472
# 468    Pipe-48940_supply            814         2053     None    0.01082
# 469    Pipe-48940_return           2054          815     None    0.01082
# 470    Pipe-51172_supply            816         2055     None    0.01330
# 471    Pipe-51172_return           2056          817     None    0.01330
# 472    Pipe-51170_supply            818         2057     None    0.00402
# 473    Pipe-51170_return           2058          819     None    0.00402
# 474    Pipe-51122_supply            842         2059     None    0.05805
# 475    Pipe-51122_return           2060          843     None    0.05805
# 476    Pipe-50944_supply            834         2061     None    0.00036
# 477    Pipe-50944_return           2062          835     None    0.00036
# 478    Pipe-50943_supply            834         2063     None    0.00038
# 479    Pipe-50943_return           2064          835     None    0.00038
# 480    Pipe-50123_supply            846         2065     None    0.02669
# 481    Pipe-50123_return           2066          847     None    0.02669
# 482    Pipe-47796_supply            746         2067     None    0.03716
# 483    Pipe-47796_return           2068          747     None    0.03716
# 484    Pipe-48054_supply            792         2069     None    0.05612
# 485    Pipe-48054_return           2070          793     None    0.05612
# 486    Pipe-49490_supply            822         2071     None    0.02091
# 487    Pipe-49490_return           2072          823     None    0.02091
# 488    Pipe-47431_supply            790         2073     None    0.03318
# 489    Pipe-47431_return           2074          791     None    0.03318
# 490    Pipe-56287_supply            794         2075     None    0.02318
# 491    Pipe-56287_return           2076          795     None    0.02318
# 492    Pipe-51398_supply            750         2077     None    0.01367
# 493    Pipe-51398_return           2078          751     None    0.01367
# 494    Pipe-48847_supply            826         2079     None    0.04383
# 495    Pipe-48847_return           2080          827     None    0.04383
# 496    Pipe-48544_supply            460         2081     None    0.01319
# 497    Pipe-48544_return           2082          461     None    0.01319
# 498    Pipe-48373_supply            624         2083     None    0.04564
# 499    Pipe-48373_return           2084          625     None    0.04564
# 500    Pipe-48203_supply            802         2085     None    0.00853
# 501    Pipe-48203_return           2086          803     None    0.00853
# 502    Pipe-48069_supply            732         2087     None    0.00930
# 503    Pipe-48069_return           2088          733     None    0.00930
# 504    Pipe-53828_supply            798         2089     None    0.04418
# 505    Pipe-53828_return           2090          799     None    0.04418
# 506    Pipe-47854_supply            780         2091     None    0.01767
# 507    Pipe-47854_return           2092          781     None    0.01767
# 508    Pipe-53243_supply            784         2093     None    0.02433
# 509    Pipe-53243_return           2094          785     None    0.02433
# 510    Pipe-47726_supply            766         2095     None    0.01904
# 511    Pipe-47726_return           2096          767     None    0.01904
# 512    Pipe-47696_supply            808         2097     None    0.03060
# 513    Pipe-47696_return           2098          809     None    0.03060
# 514    Pipe-47592_supply            786         2099     None    0.02052
# 515    Pipe-47592_return           2100          787     None    0.02052
# 516    Pipe-47438_supply            276         2101     None    0.08420
# 517    Pipe-47438_return           2102          277     None    0.08420
# 518    Pipe-47233_supply            618         2103     None    0.03411
# 519    Pipe-47233_return           2104          619     None    0.03411
# 520    Pipe-44108_supply            718         2105     None    0.00676
# 521    Pipe-44108_return           2106          719     None    0.00676
# 522    Pipe-47356_supply            788         2107     None    0.01951
# 523    Pipe-47356_return           2108          789     None    0.01951
# 524    Pipe-46753_supply            754         2109     None    0.00633
# 525    Pipe-46753_return           2110          755     None    0.00633
# 526    Pipe-46644_supply            772         2111     None    0.00621
# 527    Pipe-46644_return           2112          773     None    0.00621
# 528    Pipe-45974_supply            752         2113     None    0.04709
# 529    Pipe-45974_return           2114          753     None    0.04709
# 530    Pipe-13585_supply            740         2115     None    0.01277
# 531    Pipe-13585_return           2116          741     None    0.01277
# 532    Pipe-45913_supply            758         2117     None    0.02593
# 533    Pipe-45913_return           2118          759     None    0.02593
# 534    Pipe-45906_supply            756         2119     None    0.02134
# 535    Pipe-45906_return           2120          757     None    0.02134
# 536    Pipe-45492_supply            726         2121     None    0.04233
# 537    Pipe-45492_return           2122          727     None    0.04233
# 538    Pipe-45486_supply            744         2123     None    0.00554
# 539    Pipe-45486_return           2124          745     None    0.00554
# 540    Pipe-45240_supply            412         2125     None    0.02493
# 541    Pipe-45240_return           2126          413     None    0.02493
# 542    Pipe-44916_supply            720         2127     None    0.01936
# 543    Pipe-44916_return           2128          721     None    0.01936
# 544    Pipe-45595_supply            770         2129     None    0.02646
# 545    Pipe-45595_return           2130          771     None    0.02646
# 546    Pipe-44348_supply            962         2131     None    0.08868
# 547    Pipe-44348_return           2132          963     None    0.08868
# 548    Pipe-44034_supply            730         2133     None    0.02395
# 549    Pipe-44034_return           2134          731     None    0.02395
# 550    Pipe-44030_supply            724         2135     None    0.03109
# 551    Pipe-44030_return           2136          725     None    0.03109
# 552    Pipe-44023_supply            722         2137     None    0.00985
# 553    Pipe-44023_return           2138          723     None    0.00985
# 554    Pipe-45721_supply            738         2139     None    0.01433
# 555    Pipe-45721_return           2140          739     None    0.01433
# 556    Pipe-43821_supply            800         2141     None    0.05699
# 557    Pipe-43821_return           2142          801     None    0.05699
# 558    Pipe-43724_supply            716         2143     None    0.06172
# 559    Pipe-43724_return           2144          717     None    0.06172
# 560    Pipe-42448_supply            708         2145     None    0.03552
# 561    Pipe-42448_return           2146          709     None    0.03552
# 562    Pipe-41445_supply            704         2147     None    0.05008
# 563    Pipe-41445_return           2148          705     None    0.05008
# 564    Pipe-41403_supply            710         2149     None    0.02112
# 565    Pipe-41403_return           2150          711     None    0.02112
# 566    Pipe-40559_supply            580         2151     None    0.01959
# 567    Pipe-40559_return           2152          581     None    0.01959
# 568    Pipe-40625_supply            654         2153     None    0.03172
# 569    Pipe-40625_return           2154          655     None    0.03172
# 570    Pipe-40611_supply            688         2155     None    0.01195
# 571    Pipe-40611_return           2156          689     None    0.01195
# 572    Pipe-40225_supply            702         2157     None    0.04512
# 573    Pipe-40225_return           2158          703     None    0.04512
# 574   Pipe-117658_supply           1414         2159     None    0.01602
# 575   Pipe-117658_return           2160         1415     None    0.01602
# 576    Pipe-39760_supply            584         2161     None    0.03711
# 577    Pipe-39760_return           2162          585     None    0.03711
# 578    Pipe-39647_supply            658         2163     None    0.05386
# 579    Pipe-39647_return           2164          659     None    0.05386
# 580    Pipe-39539_supply            694         2165     None    0.02364
# 581    Pipe-39539_return           2166          695     None    0.02364
# 582    Pipe-39558_supply            694         2167     None    0.01400
# 583    Pipe-39558_return           2168          695     None    0.01400
# 584   Pipe-101711_supply           1332         2167     None    0.05698
# 585   Pipe-101711_return           2168         1333     None    0.05698
# 586   Pipe-107532_supply           1384         2169     None    0.00901
# 587   Pipe-107532_return           2170         1385     None    0.00901
# 588    Pipe-39379_supply            698         2171     None    0.09125
# 589    Pipe-39379_return           2172          699     None    0.09125
# 590    Pipe-39048_supply            610         2173     None    0.01703
# 591    Pipe-39048_return           2174          611     None    0.01703
# 592    Pipe-38461_supply            662         2175     None    0.04599
# 593    Pipe-38461_return           2176          663     None    0.04599
# 594     Pipe-3944_supply            142         2177     None    0.05156
# 595     Pipe-3944_return           2178          143     None    0.05156
# 596    Pipe-39253_supply            666         2179     None    0.18066
# 597    Pipe-39253_return           2180          667     None    0.18066
# 598    Pipe-38991_supply            676         2181     None    0.00905
# 599    Pipe-38991_return           2182          677     None    0.00905
# 600    Pipe-39019_supply            678         2183     None    0.04458
# 601    Pipe-39019_return           2184          679     None    0.04458
# 602    Pipe-38741_supply            660         2185     None    0.02427
# 603    Pipe-38741_return           2186          661     None    0.02427
# 604     Pipe-3910_supply            144         2187     None    0.03561
# 605     Pipe-3910_return           2188          145     None    0.03561
# 606    Pipe-38720_supply            664         2189     None    0.03457
# 607    Pipe-38720_return           2190          665     None    0.03457
# 608    Pipe-37285_supply            652         2191     None    0.00555
# 609    Pipe-37285_return           2192          653     None    0.00555
# 610    Pipe-36785_supply            632         2193     None    0.05853
# 611    Pipe-36785_return           2194          633     None    0.05853
# 612    Pipe-37184_supply            314         2195     None    0.06509
# 613    Pipe-37184_return           2196          315     None    0.06509
# 614    Pipe-37065_supply            890         2197     None    0.01220
# 615    Pipe-37065_return           2198          891     None    0.01220
# 616    Pipe-60559_supply            612         2199     None    0.05322
# 617    Pipe-60559_return           2200          613     None    0.05322
# 618    Pipe-36794_supply            614         2201     None    0.01154
# 619    Pipe-36794_return           2202          615     None    0.01154
# 620    Pipe-36647_supply            596         2203     None    0.07073
# 621    Pipe-36647_return           2204          597     None    0.07073
# 622    Pipe-36643_supply            598         2205     None    0.00126
# 623    Pipe-36643_return           2206          599     None    0.00126
# 624    Pipe-36568_supply            622         2207     None    0.02540
# 625    Pipe-36568_return           2208          623     None    0.02540
# 626    Pipe-36112_supply            608         2209     None    0.00872
# 627    Pipe-36112_return           2210          609     None    0.00872
# 628    Pipe-36012_supply            576         2211     None    0.00831
# 629    Pipe-36012_return           2212          577     None    0.00831
# ...
# 2313         5        True  pipe            0.355
# 2314         5        True  pipe            0.282
# 2315         5        True  pipe            0.282
# 2316         5        True  pipe            0.293
# 2317         5        True  pipe            0.293
# 2318         5        True  pipe            0.217
# 2319         5        True  pipe            0.217
# 2320         5        True  pipe            0.217
# 2321         5        True  pipe            0.217
# 2322         5        True  pipe            0.355
# 2323         5        True  pipe            0.355
# 2324         5        True  pipe            0.355
# 2325         5        True  pipe            0.355
# 2326         5        True  pipe            0.355
# 2327         5        True  pipe            0.355
# 2328         5        True  pipe            0.355
# 2329         5        True  pipe            0.355
# 2330         5        True  pipe            0.180
# 2331         5        True  pipe            0.180
# 2332         5        True  pipe            0.436
# 2333         5        True  pipe            0.436
# 2334         5        True  pipe            0.180
# 2335         5        True  pipe            0.180
# 2336         5        True  pipe            0.436
# 2337         5        True  pipe            0.436
# 2338         5        True  pipe            0.205
# 2339         5        True  pipe            0.205
# 2340         5        True  pipe            0.217
# 2341         5        True  pipe            0.217
# 2342         5        True  pipe            0.217
# 2343         5        True  pipe            0.217
# 2344         5        True  pipe            0.282
# 2345         5        True  pipe            0.282
# 2346         5        True  pipe            0.205
# 2347         5        True  pipe            0.205
# net.pipe.to_csv('pipe_inp.csv',index=False)

def calcTime(df_nodetype):
    nodes=[]
    time=[]
    vis={}

    for i in range(len(df_nodetype)):
        if df_nodetype.at[i,'Node Type']=='Sink/User':
            vis[df_nodetype.at[i,'Name'].replace('Junction-','Sink_')]=0
        else:
            vis[df_nodetype.at[i,'Name'].replace('Junction-','Junction_')]=0

    for i in range(len(net.heat_consumer)):
        nodes.append(net.heat_consumer.at[i,'name'].replace('Sink_','Junction-'))
        time.append(0)

    k=0
    while k<len(nodes):
        vis[nodes[k]]=1
        curr_t=time[k]
        for i in range(len(net.pipe)):
            if net.pipe.at[i,'from_junction']==nodes[k]:
                if vis[net.pipe.at[i,'to_junction']]==0:
                    nodes.append(net.pipe.at[i,'to_junction'])
                vis[net.pipe.at[i,'to_junction']]=1
                #time.append
            elif net.pipe.at[i,'to_junction']==nodes[k]:
                if vis[net.pipe.at[i,'from_junction']]==0:
                    nodes.append(net.pipe.at[i,'from_junction'])
                vis[net.pipe.at[i,'from_junction']]=1
                #time

# %%
## Export model to JSON

pp.to_json(net, "output/models/RHN-Full1.json")

# %%
net.res_heat_consumer.to_csv('massflow.csv',index=False) # Modes = res_heat_consumer, res_junction, res_pipe, res_circ_pump_pressure
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[633], line 1
# ----> 1 net.res_heat_consumer.to_csv('massflow.csv',index=False) # Modes = res_heat_consumer, res_junction, res_pipe, res_circ_pump_pressure
#
# File c:\Users\Victus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Victus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\Victus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Victus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Victus\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'massflow.csv'

# %%
res_heat_consumer=net.res_heat_consumer
mdot_kg_per_s_ARR=res_heat_consumer['mdot_from_kg_per_s']
print(mdot_kg_per_s_ARR)
# Out:
# 0       0.000000
# 1       0.326717
# 2       0.352318
# 3       0.252352
# 4       0.332812
# 5       0.305992
# 6       0.088994
# 7       0.310868
# 8       0.442530
# 9       0.254790
# 10      0.393767
# 11      0.514457
# 12      0.453502
# 13      0.399862
# 14      0.485199
# 15      0.074365
# 16      0.502266
# 17      0.302335
# 18      0.156044
# 19      0.214560
# 20      0.036573
# 21      3.802347
# 22      0.318183
# 23      0.063393
# 24      0.938701
# 25      0.340127
# 26      0.026820
# 27      0.058516
# 28      0.020725
# 29      0.047545
# 30      0.031696
# 31      0.026820
# 32      0.020725
# 33      0.031696
# 34      0.140196
# 35      0.031696
# 36      4.403359
# 37      0.636366
# 38      0.577850
# 39      0.368166
# 40      0.323059
# 41      0.887499
# 42      0.031696
# 43      0.599793
# 44      0.137757
# 45      0.169454
# 46      0.063393
# 47      0.430339
# 48      0.431558
# 49      0.058516
# 50      0.458379
# 51      0.026820
# 52      0.031696
# 53      0.020725
# 54      0.031696
# 55      0.036573
# 56      0.466912
# 57      0.020725
# 58      0.555906
# 59      0.036573
# 60      0.020725
# 61      0.026820
# 62      0.026820
# 63      0.031696
# 64      0.053640
# 65      0.426682
# 66      0.036573
# 67      0.471789
# 68      0.826544
# 69      0.463255
# 70      0.042668
# 71      0.026820
# 72      0.026820
# 73      0.247476
# 74      0.435216
# 75      0.553468
# 76      0.373042
# 77      0.381576
# 422     0.042668
# 423     0.404738
# 424     0.304773
# 425     0.777781
# 426     0.026820
# 427     0.036573
# 428     0.026820
# 429     0.047545
# 430     0.047545
# 431     0.042668
# 432     0.026820
# 433     0.020725
# 434     0.026820
# 435     0.053640
# 436     0.036573
# 437     0.227970
# 438     1.855458
# 439     0.443749
# 440     0.047545
# 441     0.047545
# 442     0.042668
# 443     0.020725
# 444     0.031696
# 445     0.020725
# 446     0.020725
# 447     0.026820
# 448     0.031696
# 449     0.026820
# 450     0.031696
# 451     0.036573
# 452     0.026820
# 453     0.026820
# 454     0.031696
# 455     0.031696
# 456     0.031696
# 457     0.010972
# 458     0.053640
# 459     0.053640
# 460     0.015848
# 461     0.020725
# 462     0.442530
# 463     0.349879
# 464     0.281610
# 465     0.442530
# 466     0.020725
# 467     0.026820
# 468     0.031696
# 469     0.031696
# 470     0.449845
# 471     0.397424
# 472     0.259667
# 473     0.277953
# 474     0.074365
# 475     0.290144
# 476     0.337688
# 477     3.537804
# 478     0.916757
# 479     0.304773
# 480     0.546153
# 481     0.047545
# 482     0.020725
# 483     0.042668
# 484     0.047545
# 485     0.919195
# 486     0.199931
# 487     0.231627
# 488     1.177643
# 489     0.451064
# 490     0.230408
# 491     0.424244
# 492     0.847269
# 493     0.036573
# 494     0.053640
# 495     0.459598
# Name: mdot_from_kg_per_s, dtype: float64

# %%
#Creation of a tree structure from excel data.

#roots of tree are the heaters except Ericsson
starts=[]
for i in range(len(df_heater)):
    if df_heater.at[i,'Name']!='Ericsson':
        starts.append(df_heater.at[i,'Name'])

#Goes through the df_nodetypr to store all nodes in a dict which will have their corresponding parent & children
nodes = {x: {'parent': [], 'children': {}} for x in df_nodetype['Name']}
nodes['Sarfvik']['parent']='-1'
nodes['Kirkkonummi']['parent']='-1'
vis={x: {x:-1} for x in df_nodetype['Name']}
vis['Sarfvik']=1
vis['Kirkkonummi']=1

#Here we add connections to a dictionary so as to create tree by assigning parents and children. 
    #If a connection has 'Ericsson' has one end then atleast one of 'Supply' or 'Return' should be 'True'
    #If its a connection between two nodes where none of them is 'Ericsson' then both 'Supply' and 'Return' should be 'True'.
filtered_df_connection = df_connection[
    ((df_connection['Start Node'] == 'Ericsson') | (df_connection['End Node'] == 'Ericsson')) &
    ((df_connection['Has Supply Line'] == True) | (df_connection['Has Return Line'] == True))
    |
    (~df_connection['Start Node'].eq('Ericsson') & ~df_connection['End Node'].eq('Ericsson') &
    (df_connection['Has Supply Line'] == True) & (df_connection['Has Return Line'] == True))
]

#This dictionary 'connections' has all the connections between all valid nodes. Valid connections are filtered above
    #Ericssion cases handled properly
connections = filtered_df_connection[['Start Node', 'End Node', 'Name']].values.tolist()

## Note : It has been assumed that no node has more than one parent. 
    #Since heaters are roots of the tree, two or more heaters cannot be connected to a single node (junction)
## Note : It is also assumed that there is one connection (one return and one supply) between any two nodes(junction)
bfs=[x for x in starts]
level=[0 for x in starts]
i=0
count=0
while i<len(bfs):
    j=0
    if bfs[i]=='Ericsson':
        count+=1
        i+=1
        continue
    while j<len(connections):
        connection=connections[j]
        if bfs[i]==connection[0]:
            if connection[1] in bfs:
                print(f"loop found {connection[0]}   {connection[1]}")
            bfs.append(connection[1])
            vis[connection[1]]=1
            level.append(level[i]+1)
            nodes[bfs[i]]['children'][connection[1]]=connection[2]
            nodes[connection[1]]['parent'].append(bfs[i])
            connections.pop(j)
        elif bfs[i]==connection[1]:
            if connection[0] in bfs:
                print(f"loop found {connection[1]}   {connection[0]}")
            bfs.append(connection[0])
            vis[connection[0]]=1
            level.append(level[i]+1)
            nodes[bfs[i]]['children'][connection[0]]=connection[2]
            nodes[connection[0]]['parent'].append(bfs[i])
            connections.pop(j)
        else:
            j+=1
    i+=1
print(count)
#Visualizing the tree
curr_level=0
idx=0
for ele in bfs:
    if curr_level==level[idx]:
        print(ele,end=" ")
    else:
        curr_level=level[idx]
        print()
        print(ele,end=" ")
    idx+=1
print("\n\n\nNodes:\nName\t\tparent\t\tChildren\n")
for node in nodes:
    print(node,nodes[node]['parent'],nodes[node]['children'],sep="          ")
# Out:
# loop found Junction-101660   Ericsson
# loop found Junction-22175   Junction-36301
# loop found Junction-27498   Junction-35697
# loop found Junction-127219   Junction-129143
# loop found Junction-20306   Junction-19701
# loop found Junction-9802   Junction-99110
# loop found Junction-35794   Junction-106504
# loop found Junction-31788   Junction-32382
# loop found Junction-55565   Junction-99693
# loop found Junction-17278   Junction-18843
# loop found Junction-18008   Junction-17277
# loop found Junction-2237   Junction-18841
# loop found Junction-2098   Junction-18017
# loop found Junction-18841   Junction-2228
# loop found Junction-18021   Junction-2091
# loop found Junction-2009   Junction-2007
# loop found Junction-2006   Junction-2007
# loop found Junction-2006   Junction-18027
# loop found Junction-39069   Junction-39122
# loop found Junction-70718   Junction-37764
# 2
# Sarfvik Kirkkonummi
# Junction-6737 Junction-2040
# Junction-6630 Junction-128917 Junction-2039 Junction-116892
# Junction-7838 Junction-127510 Junction-126962 Junction-3306 Junction-127533 Junction-116891
# Junction-127300 Junction-127158 Junction-20377 Junction-127514 Junction-116901
# Junction-127293 Junction-127376 Junction-105140 Junction-127516 Junction-30414 Junction-9556 Junction-118151
# Junction-127340 Junction-127332 Junction-105118 Junction-16565 Junction-127534 Junction-10018 Junction-100266 Junction-9915
# Junction-127302 Junction-111225 Junction-17746 Junction-2359 Junction-9551 Junction-100110 Junction-100264 Junction-100267 Junction-9917
# Junction-111228 Junction-14261 Junction-17656 Junction-2160 Junction-9494 Junction-99702 Junction-100107 Junction-100111 Junction-17528 Junction-12744
# Junction-33148 Junction-7795 Junction-39039 Junction-2150 Junction-2251 Junction-19194 Junction-12748
# Junction-31915 Junction-7883 Junction-59203 Junction-99634 Junction-2360 Junction-18913 Junction-19191 Junction-100388
# Junction-42407 Junction-7879 Junction-14279 Junction-99635 Junction-99375 Junction-99053 Junction-1395 Junction-18916 Junction-2340 Junction-19185 Junction-19192 Junction-33432
# Junction-43595 Junction-41442 Ericsson Junction-14292 Junction-50028 Junction-99373 Junction-99376 Junction-99054 Junction-99323 Junction-736 Junction-1396 Junction-98040 Junction-2330 Junction-100225 Junction-100231 Junction-33431 Junction-99321
# Junction-27615 Junction-17058 Junction-64780 Junction-95618 Junction-20663 Junction-22041 Junction-99090 Junction-99088 Junction-55177 Junction-37550 Junction-37764 Junction-58647 Junction-56012 Junction-67964 Junction-67966 Junction-65240
# Junction-16793 Junction-95940 Junction-95942 Junction-22039 Junction-99087 Junction-99465 Junction-99466 Junction-58790 Junction-36951 Junction-38356 Junction-58481
# Junction-71596 Junction-31657 Junction-20237 Junction-99467 Junction-99083 Junction-58784 Junction-38463 Junction-36968 Junction-37780 Junction-38353 Junction-68672
# Junction-114781 Junction-73054 Junction-34250 Junction-42312 Junction-20238 Junction-20656 Junction-99084 Junction-99085 Junction-38460 Junction-56780 Junction-37782 Junction-39409 Junction-49268 Junction-49794
# Junction-42173 Junction-72630 Junction-72632 Junction-77288 Junction-42178 Junction-42761 Junction-20659 Junction-22045 Junction-64665 Junction-65680 Junction-56779 Junction-45888 Junction-36958 Junction-66516 Junction-68862 Junction-54882
# Junction-55365 Junction-97918 Junction-73056 Junction-98413 Junction-20661 Junction-20653 Junction-22905 Junction-64664 Junction-45254 Junction-60532 Junction-36960 Junction-61715 Junction-38449
# Junction-54877 Junction-65818 Junction-60533 Junction-67029 Junction-60758 Junction-65373 Junction-38817 Junction-50972
# Junction-55179 Junction-67935 Junction-74257 Junction-61769 Junction-36962 Junction-21414 Junction-47050
# Junction-74258 Junction-75222 Junction-61767 Junction-65422 Junction-47051 Junction-48274
# Junction-57062 Hommaksenkaari_EMP Junction-36967 Junction-63760 Junction-60463 Junction-49267
# Junction-38425 Neidonkallio_EMP_1 Junction-48315 Junction-54909
# Junction-38343 Junction-39145 Junction-48312 Junction-115682 Junction-52880 Junction-55173
# Junction-37727 Junction-48934
# Junction-37731 Junction-38429 Junction-57301
# Junction-38427
#
#
# Nodes:
# Name		parent		Children
#
# Sarfvik          -1          {'Junction-6737': 'Pipe-102854'}
# Kirkkonummi          -1          {'Junction-2040': 'Pipe-58425'}
# Ericsson          ['Junction-7879', 'Junction-101660']          {}
# Hommaksenkaari_EMP          ['Junction-74258']          {}
# Junction-165          ['Junction-7434']          {'Junction-192': 'Pipe-191', 'Junction-111193': 'Pipe-116488'}
# Junction-192          ['Junction-165']          {}
# Junction-300          ['Junction-2009']          {'Junction-18899': 'Pipe-17863', 'Junction-998': 'Pipe-134497'}
# Junction-736          ['Junction-1395']          {}
# Junction-894          ['Junction-897']          {}
# Junction-897          ['Junction-9062']          {'Junction-894': 'Pipe-843', 'Junction-53865': 'Pipe-50945'}
# Junction-907          ['Junction-1036']          {'Junction-106088': 'Pipe-108299'}
# Junction-909          ['Junction-916']          {'Junction-98243': 'Pipe-99055'}
# Junction-916          ['Junction-1036']          {'Junction-909': 'Pipe-862', 'Junction-919': 'Pipe-867'}
# Junction-917          ['Junction-920']          {'Junction-97180': 'Pipe-110786'}
# Junction-919          ['Junction-916']          {'Junction-920': 'Pipe-865'}
# Junction-920          ['Junction-919']          {'Junction-917': 'Pipe-99520', 'Junction-33846': 'Pipe-99651'}
# Junction-942          ['Junction-21644']          {'Junction-1164': 'Pipe-876', 'Junction-6834': 'Pipe-20890'}
# Junction-945          ['Junction-954']          {}
# Junction-954          ['Junction-998']          {'Junction-945': 'Pipe-892'}
# Junction-956          ['Junction-998']          {}
# Junction-998          ['Junction-300']          {'Junction-956': 'Pipe-925', 'Junction-954': 'Pipe-938'}
# Junction-1036          ['Junction-105540']          {'Junction-916': 'Pipe-973', 'Junction-907': 'Pipe-975'}
# Junction-1044          ['Junction-21321']          {'Junction-1114': 'Pipe-1088', 'Junction-105540': 'Pipe-108313'}
# Junction-1114          ['Junction-1044']          {}
# Junction-1124          ['Junction-1143']          {}
# Junction-1143          ['Junction-5284']          {'Junction-1124': 'Pipe-1055', 'Junction-1928': 'Pipe-2090'}
# Junction-1164          ['Junction-942']          {}
# Junction-1395          ['Junction-2360']          {'Junction-736': 'Pipe-696', 'Junction-1396': 'Pipe-1324'}
# Junction-1396          ['Junction-1395']          {'Junction-99822': 'Pipe-100986', 'Junction-60613': 'Pipe-101229'}
# Junction-1398          ['Junction-32591']          {}
# Junction-1455          ['Junction-1471']          {'Junction-1459': 'Pipe-1382', 'Junction-105562': 'Pipe-107032'}
# Junction-1457          ['Junction-1459']          {'Junction-1941': 'Pipe-1857'}
# Junction-1459          ['Junction-1455']          {'Junction-1457': 'Pipe-1385', 'Junction-1461': 'Pipe-1394'}
# Junction-1461          ['Junction-1459']          {'Junction-1513': 'Pipe-1441'}
# Junction-1470          ['Junction-1471']          {'Junction-1472': 'Pipe-100638'}
# Junction-1471          ['Junction-1501']          {'Junction-1470': 'Pipe-1398', 'Junction-1455': 'Pipe-1881'}
# Junction-1472          ['Junction-1470']          {'Junction-1473': 'Pipe-1400'}
# Junction-1473          ['Junction-1472']          {}
# Junction-1475          ['Junction-37011']          {'Junction-1489': 'Pipe-1880'}
# Junction-1477          ['Junction-1489']          {}
# Junction-1489          ['Junction-1475']          {'Junction-1477': 'Pipe-1409', 'Junction-1510': 'Pipe-1876'}
# Junction-1491          ['Junction-1501']          {}
# Junction-1501          ['Junction-1510']          {'Junction-1491': 'Pipe-1422', 'Junction-1471': 'Pipe-1867'}
# Junction-1503          ['Junction-1510']          {'Junction-1512': 'Pipe-1437'}
# Junction-1510          ['Junction-1489']          {'Junction-1503': 'Pipe-1435', 'Junction-1501': 'Pipe-1875'}
# Junction-1512          ['Junction-1503']          {'Junction-100104': 'Pipe-101371', 'Junction-100105': 'Pipe-101372'}
# Junction-1513          ['Junction-1461']          {'Junction-100240': 'Pipe-101561', 'Junction-100241': 'Pipe-101562'}
# Junction-1694          ['Junction-1704']          {}
# Junction-1704          ['Junction-106057']          {'Junction-1694': 'Pipe-1620', 'Junction-4364': 'Pipe-99033'}
# Junction-1917          ['Junction-1928']          {}
# Junction-1928          ['Junction-1143']          {'Junction-1917': 'Pipe-1839'}
# Junction-1933          ['Junction-32353']          {}
# Junction-1941          ['Junction-1457']          {}
# Junction-2006          ['Junction-17342']          {'Junction-2007': 'Pipe-1911', 'Junction-18027': 'Pipe-17165'}
# Junction-2007          ['Junction-18021', 'Junction-2009', 'Junction-2006']          {}
# Junction-2009          ['Junction-18024']          {'Junction-300': 'Pipe-16506', 'Junction-2007': 'Pipe-16512', 'Junction-18027': 'Pipe-17163'}
# Junction-2039          ['Junction-2040']          {'Junction-3306': 'Pipe-1923', 'Junction-127533': 'Pipe-136112'}
# Junction-2040          ['Kirkkonummi']          {'Junction-2039': 'Pipe-1941', 'Junction-116892': 'Pipe-123841'}
# Junction-2042          ['Junction-2140']          {'Junction-100261': 'Pipe-101598'}
# Junction-2091          ['Junction-18024', 'Junction-18021']          {'Junction-29484': 'Pipe-28121'}
# Junction-2097          ['Junction-15414']          {'Junction-18017': 'Pipe-1992', 'Junction-18024': 'Pipe-17156'}
# Junction-2098          ['Junction-18033']          {'Junction-18017': 'Pipe-17169', 'Junction-17342': 'Pipe-19478'}
# Junction-2100          ['Junction-18013']          {'Junction-17278': 'Pipe-17140', 'Junction-15414': 'Pipe-19454'}
# Junction-2103          ['Junction-18013']          {'Junction-18033': 'Pipe-2003', 'Junction-18008': 'Pipe-17143'}
# Junction-2140          ['Junction-127406']          {'Junction-2042': 'Pipe-2017', 'Junction-2147': 'Pipe-2032'}
# Junction-2147          ['Junction-2140']          {'Junction-98860': 'Pipe-101038', 'Junction-100035': 'Pipe-101351'}
# Junction-2150          ['Junction-2160']          {'Junction-99634': 'Pipe-2036'}
# Junction-2160          ['Junction-2359']          {'Junction-2150': 'Pipe-2039', 'Junction-2251': 'Pipe-2139'}
# Junction-2226          ['Junction-2227']          {'Junction-2238': 'Pipe-2120', 'Junction-2237': 'Pipe-2121', 'Junction-18843': 'Pipe-14719'}
# Junction-2227          ['Junction-96222']          {'Junction-2226': 'Pipe-2113'}
# Junction-2228          ['Junction-18843', 'Junction-18841']          {'Junction-61093': 'Pipe-101475'}
# Junction-2237          ['Junction-2226']          {'Junction-18841': 'Pipe-19465'}
# Junction-2238          ['Junction-2226']          {'Junction-15412': 'Pipe-2123'}
# Junction-2251          ['Junction-2160']          {'Junction-2360': 'Pipe-2227'}
# Junction-2330          ['Junction-2340']          {}
# Junction-2340          ['Junction-18913']          {'Junction-2330': 'Pipe-2209'}
# Junction-2359          ['Junction-127534']          {'Junction-2160': 'Pipe-2162'}
# Junction-2360          ['Junction-2251']          {'Junction-99053': 'Pipe-100063', 'Junction-1395': 'Pipe-100987'}
# Junction-2365          ['Junction-6835']          {}
# Junction-2961          ['Junction-2964']          {'Junction-5297': 'Pipe-5099'}
# Junction-2964          ['Junction-4719']          {'Junction-2961': 'Pipe-2830'}
# Junction-3165          ['Junction-97749']          {'Junction-3224': 'Pipe-116043'}
# Junction-3224          ['Junction-3165']          {'Junction-94517': 'Pipe-3104'}
# Junction-3306          ['Junction-2039']          {}
# Junction-3397          ['Junction-3489']          {}
# Junction-3421          ['Junction-128432']          {}
# Junction-3489          ['Junction-21644']          {'Junction-3397': 'Pipe-3360'}
# Junction-3493          ['Junction-3911']          {}
# Junction-3534          ['Junction-127234']          {'Junction-3552': 'Pipe-3419', 'Junction-128432': 'Pipe-134638'}
# Junction-3552          ['Junction-3534']          {}
# Junction-3565          ['Junction-128250']          {}
# Junction-3673          ['Junction-102990']          {'Junction-4076': 'Pipe-99290', 'Junction-129282': 'Pipe-134658'}
# Junction-3911          ['Junction-5284']          {'Junction-3493': 'Pipe-3751'}
# Junction-3968          ['Junction-4076']          {'Junction-127234': 'Pipe-134654'}
# Junction-4076          ['Junction-3673']          {'Junction-3968': 'Pipe-5539', 'Junction-111157': 'Pipe-116102'}
# Junction-4079          ['Junction-4364']          {}
# Junction-4108          ['Junction-4122']          {}
# Junction-4122          ['Junction-7055']          {'Junction-4108': 'Pipe-3944'}
# Junction-4364          ['Junction-1704']          {'Junction-4079': 'Pipe-3910', 'Junction-98224': 'Pipe-99037'}
# Junction-4719          ['Junction-4720']          {'Junction-2964': 'Pipe-2927'}
# Junction-4720          ['Junction-4721']          {'Junction-4719': 'Pipe-4553'}
# Junction-4721          ['Junction-22540']          {'Junction-4720': 'Pipe-4554'}
# Junction-5284          ['Junction-5297']          {'Junction-1143': 'Pipe-2100', 'Junction-3911': 'Pipe-6042'}
# Junction-5297          ['Junction-2961']          {'Junction-5284': 'Pipe-5091', 'Junction-16220': 'Pipe-15479'}
# Junction-5699          ['Junction-6013']          {}
# Junction-5882          ['Junction-6217']          {}
# Junction-6013          ['Junction-41523']          {'Junction-5699': 'Pipe-5789', 'Junction-7434': 'Pipe-7335'}
# Junction-6217          ['Junction-51524']          {'Junction-5882': 'Pipe-5942', 'Junction-50787': 'Pipe-48205'}
# Junction-6487          ['Junction-7222']          {'Junction-7613': 'Pipe-7470'}
# Junction-6583          ['Junction-6643']          {}
# Junction-6592          ['Junction-6710']          {'Junction-6712': 'Pipe-6483'}
# Junction-6630          ['Junction-6737']          {'Junction-7838': 'Pipe-6393'}
# Junction-6643          ['Junction-32382']          {'Junction-6583': 'Pipe-6355'}
# Junction-6657          ['Junction-7028']          {}
# Junction-6710          ['Junction-100246']          {'Junction-6592': 'Pipe-6211', 'Junction-100245': 'Pipe-101570', 'Junction-100039': 'Pipe-101571'}
# Junction-6712          ['Junction-6592']          {}
# Junction-6716          ['Junction-6834']          {}
# Junction-6737          ['Sarfvik']          {'Junction-6630': 'Pipe-6499', 'Junction-128917': 'Pipe-56521'}
# Junction-6834          ['Junction-942']          {'Junction-6716': 'Pipe-6489', 'Junction-6835': 'Pipe-6607'}
# Junction-6835          ['Junction-6834']          {'Junction-2365': 'Pipe-2240', 'Junction-21896': 'Pipe-20886'}
# Junction-7028          ['Junction-7055']          {'Junction-6657': 'Pipe-6735'}
# Junction-7055          ['Junction-7518']          {'Junction-7028': 'Pipe-6825', 'Junction-4122': 'Pipe-7166'}
# Junction-7150          ['Junction-7161']          {}
# Junction-7161          ['Junction-19699']          {'Junction-7150': 'Pipe-6930', 'Junction-19666': 'Pipe-7041'}
# Junction-7222          ['Junction-14297']          {'Junction-6487': 'Pipe-6998', 'Junction-47090': 'Pipe-67461'}
# Junction-7270          ['Junction-7285']          {}
# Junction-7285          ['Junction-19666']          {'Junction-7270': 'Pipe-7047', 'Junction-7612': 'Pipe-7387'}
# Junction-7434          ['Junction-6013']          {'Junction-7443': 'Pipe-7220', 'Junction-165': 'Pipe-7923'}
# Junction-7442          ['Junction-7443']          {'Junction-111223': 'Pipe-116287'}
# Junction-7443          ['Junction-7434']          {'Junction-7442': 'Pipe-7218'}
# Junction-7518          ['Junction-18873']          {'Junction-7055': 'Pipe-7271'}
# Junction-7612          ['Junction-7285']          {'Junction-16605': 'Pipe-15855', 'Junction-21783': 'Pipe-18639'}
# Junction-7613          ['Junction-6487']          {'Junction-7614': 'Pipe-7388'}
# Junction-7614          ['Junction-7613']          {}
# Junction-7795          ['Junction-14261']          {'Junction-7883': 'Pipe-7570', 'Junction-59203': 'Pipe-55374'}
# Junction-7838          ['Junction-6630']          {}
# Junction-7879          ['Junction-7883']          {'Ericsson': 'Pipe-7663'}
# Junction-7883          ['Junction-7795']          {'Junction-7879': 'Pipe-7666'}
# Junction-8112          ['Junction-99010']          {'Junction-99082': 'Pipe-100094', 'Junction-99006': 'Pipe-100095'}
# Junction-8150          ['Junction-8165']          {}
# Junction-8165          ['Junction-111193']          {'Junction-8150': 'Pipe-7927', 'Junction-129143': 'Pipe-134865'}
# Junction-9041          ['Junction-9115']          {'Junction-31656': 'Pipe-99304'}
# Junction-9062          ['Junction-97180']          {'Junction-897': 'Pipe-8800', 'Junction-105560': 'Pipe-93431'}
# Junction-9115          ['Junction-9137']          {'Junction-9041': 'Pipe-8865'}
# Junction-9137          ['Junction-47600']          {'Junction-32355': 'Pipe-30969', 'Junction-9115': 'Pipe-97491'}
# Junction-9252          ['Junction-97937']          {'Junction-97934': 'Pipe-9213', 'Junction-99198': 'Pipe-10186'}
# Junction-9492          ['Junction-97937']          {}
# Junction-9494          ['Junction-9551']          {}
# Junction-9548          ['Junction-100368']          {'Junction-10595': 'Pipe-10260', 'Junction-99816': 'Pipe-100978'}
# Junction-9551          ['Junction-10018']          {'Junction-9494': 'Pipe-9234', 'Junction-99702': 'Pipe-9276'}
# Junction-9556          ['Junction-116901']          {'Junction-9915': 'Pipe-9282'}
# Junction-9698          ['Junction-9802']          {}
# Junction-9802          ['Junction-98869']          {'Junction-9698': 'Pipe-9500', 'Junction-99110': 'Pipe-9501'}
# Junction-9808          ['Junction-9981']          {'Junction-9809': 'Pipe-9505', 'Junction-103455': 'Pipe-103758'}
# Junction-9809          ['Junction-9808']          {'Junction-10392': 'Pipe-10048'}
# Junction-9860          ['Junction-9944']          {}
# Junction-9915          ['Junction-9556']          {'Junction-9917': 'Pipe-9609'}
# Junction-9917          ['Junction-9915']          {'Junction-17528': 'Pipe-9611', 'Junction-12744': 'Pipe-12221'}
# Junction-9944          ['Junction-10823']          {'Junction-9860': 'Pipe-9556'}
# Junction-9946          ['Junction-11647']          {}
# Junction-9981          ['Junction-19268']          {'Junction-9808': 'Pipe-11034', 'Junction-18065': 'Pipe-19750'}
# Junction-9986          ['Junction-111208']          {}
# Junction-10018          ['Junction-30414']          {'Junction-9551': 'Pipe-9275', 'Junction-100110': 'Pipe-120068'}
# Junction-10094          ['Junction-10097']          {'Junction-10095': 'Pipe-9772'}
# Junction-10095          ['Junction-10094']          {}
# Junction-10097          ['Junction-10100']          {'Junction-10094': 'Pipe-9774', 'Junction-10099': 'Pipe-9776'}
# Junction-10099          ['Junction-10097']          {}
# Junction-10100          ['Junction-42099']          {'Junction-10097': 'Pipe-9777'}
# Junction-10202          ['Junction-10519']          {'Junction-11221': 'Pipe-9854'}
# Junction-10258          ['Junction-10260']          {}
# Junction-10260          ['Junction-32355']          {'Junction-10258': 'Pipe-9918'}
# Junction-10392          ['Junction-9809']          {'Junction-111208': 'Pipe-9678'}
# Junction-10519          ['Junction-99479']          {'Junction-10202': 'Pipe-10171', 'Junction-55861': 'Pipe-52981'}
# Junction-10595          ['Junction-9548']          {}
# Junction-10823          ['Junction-11218']          {'Junction-11647': 'Pipe-11430', 'Junction-9944': 'Pipe-11515'}
# Junction-11218          ['Junction-41082']          {'Junction-10823': 'Pipe-10812', 'Junction-43191': 'Pipe-10818'}
# Junction-11221          ['Junction-10202']          {}
# Junction-11647          ['Junction-10823']          {'Junction-9946': 'Pipe-11136', 'Junction-11651': 'Pipe-11422'}
# Junction-11651          ['Junction-11647']          {}
# Junction-12744          ['Junction-9917']          {}
# Junction-12748          ['Junction-17528']          {'Junction-100388': 'Pipe-12222'}
# Junction-13700          ['Junction-66224']          {'Junction-98830': 'Pipe-13069', 'Junction-116686': 'Pipe-117591'}
# Junction-13715          ['Junction-40889']          {'Junction-16340': 'Pipe-15748', 'Junction-66224': 'Pipe-62086'}
# Junction-13742          ['Junction-13761']          {'Junction-15027': 'Pipe-14328'}
# Junction-13761          ['Junction-49142']          {'Junction-13742': 'Pipe-14317'}
# Junction-14261          ['Junction-111225']          {'Junction-33148': 'Pipe-43159', 'Junction-7795': 'Pipe-53512'}
# Junction-14279          ['Junction-59203']          {'Junction-14292': 'Pipe-13570', 'Junction-50028': 'Pipe-47438'}
# Junction-14292          ['Junction-14279']          {'Junction-29936': 'Pipe-27646', 'Junction-14297': 'Pipe-58648'}
# Junction-14297          ['Junction-14292']          {'Junction-7222': 'Pipe-57106', 'Junction-23736': 'Pipe-120881'}
# Junction-15021          ['Junction-16220']          {}
# Junction-15027          ['Junction-13742']          {}
# Junction-15412          ['Junction-2238']          {'Junction-18021': 'Pipe-100327'}
# Junction-15414          ['Junction-2100']          {'Junction-2097': 'Pipe-14716'}
# Junction-15720          ['Junction-16338']          {'Junction-16557': 'Pipe-14890'}
# Junction-16187          ['Junction-16278']          {}
# Junction-16220          ['Junction-5297']          {'Junction-15021': 'Pipe-14312', 'Junction-16232': 'Pipe-15482'}
# Junction-16232          ['Junction-16220']          {'Junction-33839': 'Pipe-32202'}
# Junction-16278          ['Junction-99368']          {'Junction-16187': 'Pipe-15532', 'Junction-100359': 'Pipe-101716'}
# Junction-16338          ['Junction-16340']          {'Junction-15720': 'Pipe-15492'}
# Junction-16340          ['Junction-13715']          {'Junction-16338': 'Pipe-15597'}
# Junction-16557          ['Junction-15720']          {}
# Junction-16565          ['Junction-105140']          {'Junction-17746': 'Pipe-16909'}
# Junction-16605          ['Junction-7612']          {}
# Junction-16793          ['Junction-17058']          {}
# Junction-16837          ['Junction-17173']          {}
# Junction-17058          ['Junction-26973']          {'Junction-16793': 'Pipe-16046'}
# Junction-17125          ['Junction-38586']          {}
# Junction-17137          ['Junction-31545']          {}
# Junction-17173          ['Junction-36258']          {'Junction-16837': 'Pipe-16354', 'Junction-27501': 'Pipe-34567'}
# Junction-17277          ['Junction-17278', 'Junction-18008']          {'Junction-99004': 'Pipe-100686'}
# Junction-17278          ['Junction-2100']          {'Junction-17277': 'Pipe-16447', 'Junction-18843': 'Pipe-19450'}
# Junction-17342          ['Junction-2098']          {'Junction-2006': 'Pipe-16513'}
# Junction-17528          ['Junction-9917']          {'Junction-12748': 'Pipe-16683'}
# Junction-17656          ['Junction-17746']          {'Junction-39039': 'Pipe-37184'}
# Junction-17746          ['Junction-16565']          {'Junction-17656': 'Pipe-16826'}
# Junction-18008          ['Junction-2103']          {'Junction-18841': 'Pipe-16445', 'Junction-17277': 'Pipe-100678'}
# Junction-18013          ['Junction-18016']          {'Junction-2100': 'Pipe-17145', 'Junction-2103': 'Pipe-17148'}
# Junction-18016          ['Junction-98841']          {'Junction-18013': 'Pipe-2004', 'Junction-99655': 'Pipe-100778'}
# Junction-18017          ['Junction-2097', 'Junction-2098']          {'Junction-20195': 'Pipe-29516'}
# Junction-18021          ['Junction-15412']          {'Junction-2091': 'Pipe-25643', 'Junction-2007': 'Pipe-96725'}
# Junction-18024          ['Junction-2097']          {'Junction-2091': 'Pipe-1988', 'Junction-2009': 'Pipe-19461'}
# Junction-18027          ['Junction-2009', 'Junction-2006']          {'Junction-100368': 'Pipe-101728'}
# Junction-18033          ['Junction-2103']          {'Junction-2098': 'Pipe-19475'}
# Junction-18065          ['Junction-9981']          {'Junction-99485': 'Pipe-100584', 'Junction-19274': 'Pipe-100789'}
# Junction-18841          ['Junction-18008', 'Junction-2237']          {'Junction-2228': 'Pipe-16199'}
# Junction-18843          ['Junction-2226', 'Junction-17278']          {'Junction-2228': 'Pipe-2112'}
# Junction-18873          ['Junction-41587']          {'Junction-18874': 'Pipe-16606', 'Junction-7518': 'Pipe-18854'}
# Junction-18874          ['Junction-18873']          {}
# Junction-18899          ['Junction-300']          {'Junction-18900': 'Pipe-17965', 'Junction-19576': 'Pipe-18648'}
# Junction-18900          ['Junction-18899']          {'Junction-19616': 'Pipe-18651', 'Junction-20691': 'Pipe-112026'}
# Junction-18913          ['Junction-19194']          {'Junction-18916': 'Pipe-17978', 'Junction-2340': 'Pipe-18234'}
# Junction-18916          ['Junction-18913']          {'Junction-98040': 'Pipe-18273'}
# Junction-19185          ['Junction-19191']          {}
# Junction-19191          ['Junction-19194']          {'Junction-19185': 'Pipe-18239', 'Junction-19192': 'Pipe-18245'}
# Junction-19192          ['Junction-19191']          {'Junction-100225': 'Pipe-101548', 'Junction-100231': 'Pipe-101549'}
# Junction-19194          ['Junction-99702']          {'Junction-18913': 'Pipe-17974', 'Junction-19191': 'Pipe-100347'}
# Junction-19266          ['Junction-19267']          {}
# Junction-19267          ['Junction-34033']          {'Junction-19266': 'Pipe-18319', 'Junction-19268': 'Pipe-18320'}
# Junction-19268          ['Junction-19267']          {'Junction-9981': 'Pipe-101464'}
# Junction-19274          ['Junction-18065']          {}
# Junction-19572          ['Junction-19573']          {}
# Junction-19573          ['Junction-19575']          {'Junction-19572': 'Pipe-18615', 'Junction-19608': 'Pipe-18642'}
# Junction-19575          ['Junction-19612']          {'Junction-19573': 'Pipe-18617', 'Junction-20655': 'Pipe-19752'}
# Junction-19576          ['Junction-18899']          {'Junction-19612': 'Pipe-18646', 'Junction-21554': 'Pipe-20528'}
# Junction-19606          ['Junction-19608']          {'Junction-20664': 'Pipe-21038'}
# Junction-19608          ['Junction-19573']          {'Junction-19606': 'Pipe-20615'}
# Junction-19611          ['Junction-19612']          {}
# Junction-19612          ['Junction-19576']          {'Junction-19611': 'Pipe-18645', 'Junction-19575': 'Pipe-20616'}
# Junction-19616          ['Junction-18900']          {}
# Junction-19621          ['Junction-20691']          {}
# Junction-19666          ['Junction-7161']          {'Junction-7285': 'Pipe-18697'}
# Junction-19699          ['Junction-20761']          {'Junction-19701': 'Pipe-18731', 'Junction-7161': 'Pipe-19779'}
# Junction-19701          ['Junction-19699', 'Junction-20306']          {'Junction-32090': 'Pipe-30400'}
# Junction-19740          ['Junction-31788']          {}
# Junction-19908          ['Junction-128439']          {'Junction-19916': 'Pipe-19511', 'Junction-21588': 'Pipe-20570'}
# Junction-19911          ['Junction-19916']          {}
# Junction-19916          ['Junction-19908']          {'Junction-19911': 'Pipe-18941', 'Junction-46131': 'Pipe-51546'}
# Junction-20194          ['Junction-20195']          {}
# Junction-20195          ['Junction-18017']          {'Junction-20194': 'Pipe-19219', 'Junction-20196': 'Pipe-19221'}
# Junction-20196          ['Junction-20195']          {}
# Junction-20230          ['Junction-20655']          {'Junction-20234': 'Pipe-19665'}
# Junction-20232          ['Junction-20234']          {}
# Junction-20234          ['Junction-20230']          {'Junction-20232': 'Pipe-19249', 'Junction-20236': 'Pipe-19251'}
# Junction-20236          ['Junction-20234']          {}
# Junction-20237          ['Junction-22039']          {'Junction-20238': 'Pipe-19253', 'Junction-20656': 'Pipe-112019'}
# Junction-20238          ['Junction-20237']          {}
# Junction-20284          ['Junction-31466']          {}
# Junction-20306          ['Junction-20819']          {'Junction-22022': 'Pipe-19295', 'Junction-19701': 'Pipe-19805'}
# Junction-20377          ['Junction-126962']          {'Junction-127376': 'Pipe-14292', 'Junction-105140': 'Pipe-109073'}
# Junction-20653          ['Junction-22045']          {}
# Junction-20655          ['Junction-19575']          {'Junction-20230': 'Pipe-19671', 'Junction-21636': 'Pipe-20854'}
# Junction-20656          ['Junction-20237']          {'Junction-20659': 'Pipe-19674', 'Junction-22045': 'Pipe-21042'}
# Junction-20659          ['Junction-20656']          {'Junction-20661': 'Pipe-19676'}
# Junction-20661          ['Junction-20659']          {}
# Junction-20663          ['Junction-20664']          {'Junction-22039': 'Pipe-21889'}
# Junction-20664          ['Junction-19606']          {'Junction-20663': 'Pipe-19679', 'Junction-22041': 'Pipe-21037'}
# Junction-20691          ['Junction-18900']          {'Junction-19621': 'Pipe-18655'}
# Junction-20761          ['Junction-54179']          {'Junction-19699': 'Pipe-18725'}
# Junction-20819          ['Junction-116686']          {'Junction-20306': 'Pipe-13057'}
# Junction-21263          ['Junction-48555']          {'Junction-21264': 'Pipe-20266', 'Junction-23009': 'Pipe-21987'}
# Junction-21264          ['Junction-21263']          {'Junction-34156': 'Pipe-32494', 'Junction-47603': 'Pipe-45240'}
# Junction-21265          ['Junction-26248']          {'Junction-23720': 'Pipe-22630', 'Junction-25543': 'Pipe-34498'}
# Junction-21321          ['Junction-47600']          {'Junction-1044': 'Pipe-20311'}
# Junction-21414          ['Junction-38817']          {}
# Junction-21554          ['Junction-19576']          {}
# Junction-21588          ['Junction-19908']          {}
# Junction-21635          ['Junction-21636']          {}
# Junction-21636          ['Junction-20655']          {'Junction-21635': 'Pipe-20617', 'Junction-21859': 'Pipe-20852'}
# Junction-21644          ['Junction-111147']          {'Junction-3489': 'Pipe-20627', 'Junction-942': 'Pipe-20978'}
# Junction-21646          ['Junction-21896']          {}
# Junction-21775          ['Junction-21783']          {}
# Junction-21783          ['Junction-7612']          {'Junction-21775': 'Pipe-20766'}
# Junction-21859          ['Junction-21636']          {}
# Junction-21896          ['Junction-6835']          {'Junction-21646': 'Pipe-20635'}
# Junction-22022          ['Junction-20306']          {'Junction-111147': 'Pipe-117067'}
# Junction-22039          ['Junction-20663']          {'Junction-20237': 'Pipe-21888'}
# Junction-22041          ['Junction-20664']          {}
# Junction-22045          ['Junction-20656']          {'Junction-20653': 'Pipe-21882', 'Junction-22905': 'Pipe-21884'}
# Junction-22175          ['Junction-34444']          {'Junction-36301': 'Pipe-21177', 'Junction-99286': 'Pipe-100339'}
# Junction-22540          ['Junction-23339']          {'Junction-4721': 'Pipe-4555', 'Junction-23337': 'Pipe-22270'}
# Junction-22905          ['Junction-22045']          {}
# Junction-22908          ['Junction-22919']          {}
# Junction-22919          ['Junction-31469']          {'Junction-22908': 'Pipe-21896', 'Junction-31466': 'Pipe-29989'}
# Junction-23009          ['Junction-21263']          {}
# Junction-23337          ['Junction-22540']          {'Junction-41683': 'Pipe-39618'}
# Junction-23339          ['Junction-36767']          {'Junction-22540': 'Pipe-21280'}
# Junction-23720          ['Junction-21265']          {}
# Junction-23736          ['Junction-14297']          {}
# Junction-24920          ['Junction-26246']          {}
# Junction-25321          ['Junction-25543']          {}
# Junction-25472          ['Junction-25486']          {}
# Junction-25486          ['Junction-29632']          {'Junction-25472': 'Pipe-24327', 'Junction-31990': 'Pipe-24334'}
# Junction-25489          ['Junction-28618']          {}
# ...
# Junction-101919          ['Junction-105560']          {'Junction-102990': 'Pipe-104142'}
# Junction-102036          ['Junction-28618']          {'Junction-102637': 'Pipe-103760', 'Junction-48688': 'Pipe-104734'}
# Junction-102277          ['Junction-94950']          {'Junction-103322': 'Pipe-104517', 'Junction-95215': 'Pipe-104735'}
# Junction-102637          ['Junction-102036']          {}
# Junction-102990          ['Junction-101919']          {'Junction-3673': 'Pipe-103402'}
# Junction-103003          ['Junction-128637']          {}
# Junction-103293          ['Junction-103322']          {}
# Junction-103313          ['Junction-103455']          {'Junction-128816': 'Pipe-135821'}
# Junction-103322          ['Junction-102277']          {'Junction-103293': 'Pipe-104469'}
# Junction-103455          ['Junction-9808']          {'Junction-103313': 'Pipe-104496'}
# Junction-105118          ['Junction-105140']          {}
# Junction-105140          ['Junction-20377']          {'Junction-105118': 'Pipe-106599', 'Junction-16565': 'Pipe-109052'}
# Junction-105274          ['Junction-99237']          {'Junction-50281': 'Pipe-106740'}
# Junction-105276          ['Junction-99111']          {'Junction-105282': 'Pipe-110957'}
# Junction-105282          ['Junction-105276']          {'Junction-99237': 'Pipe-110953'}
# Junction-105411          ['Junction-30008']          {}
# Junction-105540          ['Junction-1044']          {'Junction-1036': 'Pipe-106999', 'Junction-105814': 'Pipe-107272'}
# Junction-105543          ['Junction-105560']          {}
# Junction-105560          ['Junction-9062']          {'Junction-105543': 'Pipe-107007', 'Junction-101919': 'Pipe-107018'}
# Junction-105562          ['Junction-1455']          {}
# Junction-105810          ['Junction-105811']          {}
# Junction-105811          ['Junction-105812']          {'Junction-105810': 'Pipe-107262'}
# Junction-105812          ['Junction-105814']          {'Junction-105813': 'Pipe-107263', 'Junction-105811': 'Pipe-107264'}
# Junction-105813          ['Junction-105812']          {}
# Junction-105814          ['Junction-105540']          {'Junction-105812': 'Pipe-107265'}
# Junction-106045          ['Junction-106048']          {'Junction-98228': 'Pipe-110839'}
# Junction-106048          ['Junction-106088']          {'Junction-106045': 'Pipe-107523', 'Junction-106055': 'Pipe-107556'}
# Junction-106055          ['Junction-106048']          {'Junction-41284': 'Pipe-107532', 'Junction-106057': 'Pipe-107551'}
# Junction-106057          ['Junction-106055']          {'Junction-1704': 'Pipe-110833'}
# Junction-106088          ['Junction-907']          {'Junction-106048': 'Pipe-107559'}
# Junction-106090          ['Junction-106092']          {}
# Junction-106092          ['Junction-31990']          {'Junction-106090': 'Pipe-107568', 'Junction-35794': 'Pipe-107571'}
# Junction-106326          ['Junction-106504']          {'Junction-106327': 'Pipe-107814', 'Junction-106501': 'Pipe-108032'}
# Junction-106327          ['Junction-106326']          {}
# Junction-106501          ['Junction-106326']          {}
# Junction-106504          ['Junction-35760', 'Junction-35794']          {'Junction-106326': 'Pipe-108035'}
# Junction-106507          ['Junction-107214']          {}
# Junction-107214          ['Junction-25543']          {'Junction-106507': 'Pipe-108042', 'Junction-35760': 'Pipe-109543'}
# Junction-111142          ['Junction-111147']          {}
# Junction-111147          ['Junction-22022']          {'Junction-111142': 'Pipe-114188', 'Junction-21644': 'Pipe-123849'}
# Junction-111150          ['Junction-111155']          {}
# Junction-111155          ['Junction-48688']          {'Junction-111150': 'Pipe-114194', 'Junction-27084': 'Pipe-114199'}
# Junction-111157          ['Junction-4076']          {'Junction-111160': 'Pipe-114207', 'Junction-98397': 'Pipe-119990'}
# Junction-111160          ['Junction-111157']          {}
# Junction-111171          ['Junction-111193']          {}
# Junction-111193          ['Junction-165']          {'Junction-111171': 'Pipe-114222', 'Junction-8165': 'Pipe-123857'}
# Junction-111196          ['Junction-111208']          {}
# Junction-111208          ['Junction-10392']          {'Junction-111196': 'Pipe-114238', 'Junction-9986': 'Pipe-116559'}
# Junction-111213          ['Junction-111223']          {}
# Junction-111223          ['Junction-7442']          {'Junction-111213': 'Pipe-114253', 'Junction-127219': 'Pipe-134839'}
# Junction-111225          ['Junction-127332']          {'Junction-111228': 'Pipe-114272', 'Junction-14261': 'Pipe-118794'}
# Junction-111228          ['Junction-111225']          {}
# Junction-114744          ['Junction-37303']          {'Junction-34334': 'Pipe-117600', 'Junction-117594': 'Pipe-120849'}
# Junction-114781          ['Junction-71596']          {'Junction-42173': 'Pipe-117658', 'Junction-72630': 'Pipe-119922'}
# Junction-115208          ['Junction-36469']          {'Junction-37596': 'Pipe-118053', 'Junction-117566': 'Pipe-120820'}
# Junction-115682          ['Junction-48315']          {}
# Junction-116686          ['Junction-13700']          {'Junction-20819': 'Pipe-19851', 'Junction-118160': 'Pipe-121410'}
# Junction-116837          ['Junction-98465']          {}
# Junction-116891          ['Junction-116892']          {'Junction-116901': 'Pipe-120098'}
# Junction-116892          ['Junction-2040']          {'Junction-116891': 'Pipe-120080'}
# Junction-116901          ['Junction-116891']          {'Junction-9556': 'Pipe-120100', 'Junction-118151': 'Pipe-121429'}
# Junction-117566          ['Junction-115208']          {}
# Junction-117594          ['Junction-114744']          {}
# Junction-118151          ['Junction-116901']          {}
# Junction-118160          ['Junction-116686']          {}
# Junction-120721          ['Junction-120722']          {'Junction-120847': 'Pipe-124743'}
# Junction-120722          ['Junction-97373']          {'Junction-120721': 'Pipe-124597'}
# Junction-120847          ['Junction-120721']          {'Junction-97753': 'Pipe-126196'}
# Junction-122930          ['Junction-26248']          {'Junction-34033': 'Pipe-127195'}
# Junction-126962          ['Junction-128917']          {'Junction-127158': 'Pipe-131360', 'Junction-20377': 'Pipe-135153'}
# Junction-127158          ['Junction-126962']          {}
# Junction-127160          ['Junction-127162']          {'Junction-99013': 'Pipe-135626'}
# Junction-127162          ['Junction-127171']          {'Junction-127160': 'Pipe-131566', 'Junction-127164': 'Pipe-131569'}
# Junction-127164          ['Junction-127162']          {'Junction-99010': 'Pipe-131577'}
# Junction-127171          ['Junction-65528']          {'Junction-127162': 'Pipe-131572'}
# Junction-127174          ['Junction-127181']          {'Junction-96900': 'Pipe-135590'}
# Junction-127181          ['Junction-127197']          {'Junction-127174': 'Pipe-131578', 'Junction-127182': 'Pipe-131583'}
# Junction-127182          ['Junction-127181']          {'Junction-127184': 'Pipe-131587'}
# Junction-127184          ['Junction-127182']          {'Junction-94894': 'Pipe-135408'}
# Junction-127197          ['Junction-127314']          {'Junction-127181': 'Pipe-131601'}
# Junction-127208          ['Junction-127219']          {'Junction-128333': 'Pipe-132673', 'Junction-128334': 'Pipe-132674'}
# Junction-127219          ['Junction-111223']          {'Junction-127208': 'Pipe-131613', 'Junction-129143': 'Pipe-134826'}
# Junction-127222          ['Junction-127234']          {}
# Junction-127234          ['Junction-3968']          {'Junction-127222': 'Pipe-131624', 'Junction-3534': 'Pipe-134620'}
# Junction-127246          ['Junction-99755']          {'Junction-99880': 'Pipe-120033', 'Junction-128253': 'Pipe-131630'}
# Junction-127265          ['Junction-66675']          {'Junction-128234': 'Pipe-131640', 'Junction-98465': 'Pipe-135646'}
# Junction-127268          ['Junction-127286']          {'Junction-128285': 'Pipe-132621', 'Junction-128286': 'Pipe-132622'}
# Junction-127286          ['Junction-130756']          {'Junction-127268': 'Pipe-132625', 'Junction-66675': 'Pipe-135651'}
# Junction-127291          ['Junction-127314']          {'Junction-98264': 'Pipe-131670'}
# Junction-127293          ['Junction-127300']          {}
# Junction-127300          ['Junction-127510']          {'Junction-127293': 'Pipe-131675'}
# Junction-127302          ['Junction-127332']          {}
# Junction-127314          ['Junction-96962']          {'Junction-127291': 'Pipe-131690', 'Junction-127197': 'Pipe-135414'}
# Junction-127332          ['Junction-127376']          {'Junction-127302': 'Pipe-131686', 'Junction-111225': 'Pipe-136122'}
# Junction-127340          ['Junction-127376']          {}
# Junction-127376          ['Junction-20377']          {'Junction-127340': 'Pipe-131720', 'Junction-127332': 'Pipe-131751'}
# Junction-127378          ['Junction-127380']          {'Junction-127442': 'Pipe-131752', 'Junction-127464': 'Pipe-131835'}
# Junction-127380          ['Junction-127446']          {'Junction-127378': 'Pipe-131753', 'Junction-127411': 'Pipe-131816'}
# Junction-127382          ['Junction-127383']          {'Junction-127924': 'Pipe-132592'}
# Junction-127383          ['Junction-127387']          {'Junction-127382': 'Pipe-131754'}
# Junction-127385          ['Junction-98040']          {'Junction-127386': 'Pipe-131757'}
# Junction-127386          ['Junction-127385']          {'Junction-127387': 'Pipe-131759'}
# Junction-127387          ['Junction-127386']          {'Junction-127383': 'Pipe-131758', 'Junction-127406': 'Pipe-131778'}
# Junction-127406          ['Junction-127387']          {'Junction-2140': 'Pipe-135716'}
# Junction-127409          ['Junction-128160']          {'Junction-127410': 'Pipe-131781'}
# Junction-127410          ['Junction-127409']          {}
# Junction-127411          ['Junction-127380']          {'Junction-100427': 'Pipe-131782'}
# Junction-127412          ['Junction-127438']          {'Junction-127413': 'Pipe-131783'}
# Junction-127413          ['Junction-127412']          {}
# Junction-127414          ['Junction-127417']          {'Junction-100277': 'Pipe-131784'}
# Junction-127417          ['Junction-127438']          {'Junction-127414': 'Pipe-131874', 'Junction-127596': 'Pipe-131963'}
# Junction-127438          ['Junction-127442']          {'Junction-127417': 'Pipe-131806', 'Junction-127412': 'Pipe-131870'}
# Junction-127442          ['Junction-127378']          {'Junction-127438': 'Pipe-131808', 'Junction-127493': 'Pipe-131864'}
# Junction-127446          ['Junction-128164']          {'Junction-127380': 'Pipe-131813'}
# Junction-127464          ['Junction-127378']          {}
# Junction-127493          ['Junction-127442']          {}
# Junction-127510          ['Junction-128917']          {'Junction-127300': 'Pipe-131882'}
# Junction-127514          ['Junction-127533']          {'Junction-127516': 'Pipe-131889', 'Junction-30414': 'Pipe-134974'}
# Junction-127516          ['Junction-127514']          {'Junction-127534': 'Pipe-131906'}
# Junction-127533          ['Junction-2039']          {'Junction-127514': 'Pipe-131905'}
# Junction-127534          ['Junction-127516']          {'Junction-2359': 'Pipe-134525'}
# Junction-127537          ['Junction-128246']          {'Junction-127538': 'Pipe-131909'}
# Junction-127538          ['Junction-127537']          {'Junction-128247': 'Pipe-135691'}
# Junction-127596          ['Junction-127417']          {}
# Junction-127650          ['Junction-128250']          {}
# Junction-127924          ['Junction-127382']          {'Junction-99593': 'Pipe-131780', 'Junction-128160': 'Pipe-132516'}
# Junction-128160          ['Junction-127924']          {'Junction-127409': 'Pipe-132491', 'Junction-128164': 'Pipe-132497'}
# Junction-128162          ['Junction-128164']          {}
# Junction-128164          ['Junction-128160']          {'Junction-128162': 'Pipe-132494', 'Junction-127446': 'Pipe-132496'}
# Junction-128230          ['Junction-128234']          {'Junction-128231': 'Pipe-132556'}
# Junction-128231          ['Junction-128230']          {}
# Junction-128233          ['Junction-128234']          {}
# Junction-128234          ['Junction-127265']          {'Junction-128233': 'Pipe-132558', 'Junction-128230': 'Pipe-132574'}
# Junction-128246          ['Junction-100272']          {'Junction-127537': 'Pipe-131913', 'Junction-99540': 'Pipe-132571'}
# Junction-128247          ['Junction-127538']          {'Junction-99544': 'Pipe-135606', 'Junction-100271': 'Pipe-135690'}
# Junction-128250          ['Junction-129282']          {'Junction-127650': 'Pipe-132023', 'Junction-3565': 'Pipe-132576'}
# Junction-128253          ['Junction-127246']          {}
# Junction-128285          ['Junction-127268']          {}
# Junction-128286          ['Junction-127268']          {}
# Junction-128333          ['Junction-127208']          {}
# Junction-128334          ['Junction-127208']          {}
# Junction-128432          ['Junction-3534']          {'Junction-128433': 'Pipe-132770', 'Junction-3421': 'Pipe-134634'}
# Junction-128433          ['Junction-128432']          {}
# Junction-128439          ['Junction-41442']          {'Junction-128440': 'Pipe-132776', 'Junction-19908': 'Pipe-134938'}
# Junction-128440          ['Junction-128439']          {}
# Junction-128595          ['Junction-128816']          {}
# Junction-128600          ['Junction-128637']          {}
# Junction-128637          ['Junction-128816']          {'Junction-128600': 'Pipe-132952', 'Junction-103003': 'Pipe-135774'}
# Junction-128816          ['Junction-103313']          {'Junction-128595': 'Pipe-132930', 'Junction-128637': 'Pipe-135810'}
# Junction-128917          ['Junction-6737']          {'Junction-127510': 'Pipe-133222', 'Junction-126962': 'Pipe-135079'}
# Junction-129043          ['Junction-129248']          {'Junction-98729': 'Pipe-135674'}
# Junction-129097          ['Junction-129145']          {'Junction-129256': 'Pipe-133572'}
# Junction-129103          ['Junction-100368']          {'Junction-129248': 'Pipe-133428', 'Junction-129250': 'Pipe-133564'}
# Junction-129106          ['Junction-129111']          {'Junction-129107': 'Pipe-133431'}
# Junction-129107          ['Junction-129106']          {}
# Junction-129109          ['Junction-129111']          {}
# Junction-129111          ['Junction-129113']          {'Junction-129109': 'Pipe-133434', 'Junction-129106': 'Pipe-133436'}
# Junction-129113          ['Junction-129143']          {'Junction-129111': 'Pipe-133437'}
# Junction-129143          ['Junction-8165', 'Junction-127219']          {'Junction-129113': 'Pipe-133456'}
# Junction-129145          ['Junction-129171']          {'Junction-129097': 'Pipe-133423', 'Junction-129148': 'Pipe-133485'}
# Junction-129148          ['Junction-129145']          {'Junction-129149': 'Pipe-133470'}
# Junction-129149          ['Junction-129148']          {}
# Junction-129171          ['Junction-129191']          {'Junction-129145': 'Pipe-133486'}
# Junction-129191          ['Junction-98224']          {'Junction-129171': 'Pipe-133494', 'Junction-130756': 'Pipe-135703'}
# Junction-129247          ['Junction-97159']          {'Junction-129285': 'Pipe-133531', 'Junction-50543': 'Pipe-133562'}
# Junction-129248          ['Junction-129103']          {'Junction-129043': 'Pipe-133563'}
# Junction-129250          ['Junction-129103']          {}
# Junction-129256          ['Junction-129097']          {}
# Junction-129272          ['Junction-129282']          {}
# Junction-129282          ['Junction-3673']          {'Junction-129272': 'Pipe-133591', 'Junction-128250': 'Pipe-134648'}
# Junction-129285          ['Junction-129247']          {}
# Junction-129775          ['Junction-95634']          {'Junction-95020': 'Pipe-132017', 'Junction-94950': 'Pipe-136115'}
# Junction-130756          ['Junction-129191']          {'Junction-127286': 'Pipe-135639'}
# Junction-131108          ['Junction-99540']          {}
# Kantvik_EMP          ['Junction-41587']          {}
# Kummihovi_EMP          ['Junction-41572']          {}
# Neidonkallio_EMP_1          ['Junction-36967']          {}
# Neidonkallio_EMP_2          ['Junction-46680']          {}

# %%
# #Creation of a tree structure from excel data.

# #roots of tree are the heaters except Ericsson
# starts=[]
# for i in range(len(net.circ_pump_pressure)):
#     if (net.circ_pump_pressure).at[i,'name']!='Ericsson':
#         starts.append((net.circ_pump_pressure).at[i,'name'])

# bfs=[]
# level=[]
# vis=[]
# i=0
# while i<len(net.circ_pump_pressure):
#     name=net.circ_pump_pressure.at[i,'name']
#     return_junction=net.circ_pump_pressure.at[i,'return_junction']
#     flow_junction=net.circ_pump_pressure.at[i,'flow_junction']
#     if net.junction.at[return_junction,'name'].endswith('_return') and net.junction.at[flow_junction,'name'].endswith('_supply'):
#         bfs.append([flow_junction,-1])
#         level.append(0)
#     i+=1

# i=0
# while i<len(bfs):
#     vis.append(bfs[i][0])
#     k=0
#     while k<len(net.pipe):
#         from_junction=net.pipe.at[k,'from_junction']
#         to_junction=net.pipe.at[k,'to_junction']
#         if from_junction==bfs[i][0]:
#             if to_junction in vis:
#                 print('loop found',end="")
#             else:
#                 bfs.append([to_junction,from_junction])
#                 level.append(level[i]+1)
#         elif to_junction==bfs[i][0]:
#             if from_junction in vis:
#                 print('loop found',end="")
#             else:
#                 bfs.append([from_junction,to_junction])
#                 level.append(level[i]+1)
#         k+=1
#     i+=1

# #Visualizing the tree
# print(starts)
# curr_lev=1
# for i in range(len(starts),len(bfs)):
#     if curr_lev==level[i]:
#         print(bfs[i],end=" ")
#     else:
#         curr_lev+=1
#         print()
#         print(bfs[i],end=" ")

# %%
#Accommodating changes of network

"""
    1. Change in sink demand
    2. Leak/removal of pipes
    3. Addtion/subtraction of sink(user)
    4. Addition of storage tank
    5. Changes in environment condition
"""
# Out:
# '\n    1. Change in sink demand\n    2. Leak/removal of pipes\n    3. Addtion/subtraction of sink(user)\n    4. Addition of storage tank\n    5. Changes in environment condition\n'
